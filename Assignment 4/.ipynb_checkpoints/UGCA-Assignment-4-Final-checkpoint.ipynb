# %% [markdown]
# ## UGCA Group Assignment 4

# %% [markdown]
# # Group Members
# 1. Chetna Singhal
# 2. David Kinman
# 3. Prajval Gupta
# 4. Subhayu Chakravarty
# 5. Whitt Hyde

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import time
import re
from urllib.request import urlopen
import json
from pandas.io.json import json_normalize
import pandas as pd, numpy as np
from sklearn.linear_model import LogisticRegression
import seaborn as sn
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import nltk

# %%
### Scraping Instagram for urls, likes, and  via Selenium ###
username='manofthekinfolk'
account='natgeo'
browser = webdriver.Chrome(executable_path='C:\\Users\\david\\Downloads\\chromedriver\\chromedriver.exe')
browser.get('https://www.instagram.com/'+account+'/?hl=en')
Pagelength = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %% [markdown]
# # Data Collection

# %%
number_of_images = 10000
browser = webdriver.Chrome(executable_path='C:\\Users\\david\\Downloads\\chromedriver\\chromedriver.exe')
browser.get('https://www.instagram.com/'+account+'/?hl=en')
last_height = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
links=[]
while len(links) < number_of_images:
    source = browser.page_source
    data=bs(source, 'html.parser')
    body = data.find('body')
    script = body.find('span')
    for link in script.findAll('a'):
         if re.match("/p", link.get('href')):
            pre_link = links.append('https://www.instagram.com'+link.get('href'))
            if pre_link not in links:
                links.append(pre_link)
    while True:
        browser.execute_script("window.scrollTo(0, document.body.scrollHeight/4.0);")
        time.sleep(5)
        new_height = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        if last_height == new_height:
            break
        last_height = new_height
#     return links

# %%
len(links)
# Out:
# 10021

# %%
result=pd.DataFrame()
for i in range(len(links)):
    try:
        page = urlopen(links[i]).read()
        data=bs(page, 'html.parser')
        body = data.find('body')
        script = body.find('script')
        raw = script.text.strip().replace('window._sharedData =', '').replace(';', '')
        json_data=json.loads(raw)
        posts =json_data['entry_data']['PostPage'][0]['graphql']
        posts= json.dumps(posts)
        posts = json.loads(posts)
        x = pd.DataFrame.from_dict(json_normalize(posts), orient='columns') 
        x.columns =  x.columns.str.replace("shortcode_media.", "")
        result=result.append(x)
       
    except:
        np.nan
#Just check for the duplicates
result = result.drop_duplicates(subset = 'shortcode')
result.index = range(len(result.index))

# %%
result2 = pd.concat([result.loc[:,'display_url'],result.loc[:,'edge_media_to_caption.edges'],result.loc[:,'edge_media_to_parent_comment.count'],result.loc[:,'edge_media_preview_like.count']], axis='columns')
result2 = result2.rename(columns={"display_url":"URL","edge_media_to_caption.edges":"UnfinishedCaption","edge_media_to_parent_comment.count":"Comment Count","edge_media_preview_like.count":"Like Count"})
result2['UnfinishedCaption']=result2['UnfinishedCaption'].astype(str)
result2.loc[:, 'Caption'] = result2.UnfinishedCaption.map(lambda x: x[20:-4])
result2 = pd.concat([result2.loc[:,'URL'],result2.loc[:,'Caption'],result2.loc[:,'Like Count'],result2.loc[:,'Comment Count']], axis='columns')
word = 'Video'   
result3 = result2[~result2["Caption"].str.contains(word, na=False)]
word = 'Photos'
result4 = result3[~result3["Caption"].str.contains(word, na=False)]
result4
# Out:
#                                                     URL  \
# 1     https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 3     https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 4     https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 6     https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 7     https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# ...                                                 ...
# 1087  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 1092  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 1093  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 1095  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 1097  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
#
#                                                 Caption  Like Count  \
# 1     Photo by @brianskerry | The U.S. Civil War sub...       84699
# 3     Photo by William Albert Allard @williamalberta...      168260
# 4     Photo by David Guttenfelder @dguttenfelder | T...      252696
# 6     Photo by Nichole Sobecki @nicholesobecki | Omm...      114367
# 7     Photo by @lucasfogliaphoto | Ashley Klein does...      287042
# ...                                                 ...         ...
# 1087  Photo by Diana Markosian @markosian | A mother...      248822
# 1092  Photo by Keith Ladzinski @ladzinski | An engin...      229292
# 1093  Photo by Michael Yamashita @yamashitaphoto | A...      558047
# 1095  Photo by Joel Sartore @joelsartore | This red-...      442934
# 1097  Photo by Ismail Ferdous @ismailferdous | A you...      228022
#
#       Comment Count
# 1               268
# 3               519
# 4               491
# 6               297
# 7              1717
# ...             ...
# 1087            604
# 1092            652
# 1093           1748
# 1095           1451
# 1097            897
#
# [957 rows x 4 columns]

# %%
export_csv = result4.to_csv (r'C:\Users\david\Pictures\UGCA\Final\Instagram_dataframe.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path

# %%
unedited_csv=result.to_csv (r'C:\Users\david\Pictures\UGCA\Final\Unedited_Instagram_dataframe.csv', index = None, header=True)

# %%
result4.index = range(len(result4.index))
result4
# Out:
#                                                    URL  \
# 0    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 1    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 2    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 3    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 4    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# ..                                                 ...
# 952  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 953  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 954  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 955  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 956  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
#
#                                                Caption  Like Count  \
# 0    Photo by @brianskerry | The U.S. Civil War sub...       84699
# 1    Photo by William Albert Allard @williamalberta...      168260
# 2    Photo by David Guttenfelder @dguttenfelder | T...      252696
# 3    Photo by Nichole Sobecki @nicholesobecki | Omm...      114367
# 4    Photo by @lucasfogliaphoto | Ashley Klein does...      287042
# ..                                                 ...         ...
# 952  Photo by Diana Markosian @markosian | A mother...      248822
# 953  Photo by Keith Ladzinski @ladzinski | An engin...      229292
# 954  Photo by Michael Yamashita @yamashitaphoto | A...      558047
# 955  Photo by Joel Sartore @joelsartore | This red-...      442934
# 956  Photo by Ismail Ferdous @ismailferdous | A you...      228022
#
#      Comment Count
# 0              268
# 1              519
# 2              491
# 3              297
# 4             1717
# ..             ...
# 952            604
# 953            652
# 954           1748
# 955           1451
# 956            897
#
# [957 rows x 4 columns]

# %% [markdown]
# ### Importing data from csv to Dataframe

# %%
full = pd.read_csv(r'Instagram_dataframe.csv')

# %% [markdown]
# ### Test data set

# %%
full = pd.concat([full.loc[0:2,:],full.loc[4:188,:],full.loc[275:340,:],full.loc[341:381,:],full.loc[383:558,:],full.loc[560:672,:],full.loc[674:695,:],full.loc[697:705,:],full.loc[707:774,:],full.loc[776:870,:],full.loc[872:945,:],full.loc[947:,:]])
full.index = range(len(full.index))
full
# Out:
#                                                    URL  \
# 0    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 1    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 2    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 3    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 4    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# ..                                                 ...
# 857  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 858  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 859  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 860  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 861  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
#
#                                                Caption  Like Count  \
# 0    Photo by @brianskerry | The U.S. Civil War sub...       84699
# 1    Photo by William Albert Allard @williamalberta...      168260
# 2    Photo by David Guttenfelder @dguttenfelder | T...      252696
# 3    Photo by @lucasfogliaphoto | Ashley Klein does...      287042
# 4    Photo by @gerdludwig | Known for their elabora...      149658
# ..                                                 ...         ...
# 857  Photo by Diana Markosian @markosian | A mother...      248822
# 858  Photo by Keith Ladzinski @ladzinski | An engin...      229292
# 859  Photo by Michael Yamashita @yamashitaphoto | A...      558047
# 860  Photo by Joel Sartore @joelsartore | This red-...      442934
# 861  Photo by Ismail Ferdous @ismailferdous | A you...      228022
#
#      Comment Count
# 0              268
# 1              519
# 2              491
# 3             1717
# 4              394
# ..             ...
# 857            604
# 858            652
# 859           1748
# 860           1451
# 861            897
#
# [862 rows x 4 columns]

# %% [markdown]
# ### Actual Dataset

# %%
api_df = full.loc[0:538,:]
api_df = pd.concat([full.loc[0:6,:],full.loc[12:186,:],full.loc[193:250,:],full.loc[254:290,:],full.loc[295:466,:],full.loc[491:541,:]])
api_df
# Out:
#                                                    URL  \
# 0    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 1    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 2    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 3    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 4    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# ..                                                 ...
# 537  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 538  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 539  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 540  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 541  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
#
#                                                Caption  Like Count  \
# 0    Photo by @brianskerry | The U.S. Civil War sub...       84699
# 1    Photo by William Albert Allard @williamalberta...      168260
# 2    Photo by David Guttenfelder @dguttenfelder | T...      252696
# 3    Photo by @lucasfogliaphoto | Ashley Klein does...      287042
# 4    Photo by @gerdludwig | Known for their elabora...      149658
# ..                                                 ...         ...
# 537  Photo by Ira Block @irablockphoto | A red-tail...      454383
# 538  Photo by Nora Lorek @noralorek | Three years a...      122497
# 539  Photo by Ami Vitale @amivitale | On Monday, @U...      493142
# 540  Photo by Paolo Woods  and Gabriele Galimberti ...      331186
# 541  Photo by Muhammed Muheisen @mmuheisen | Zahra ...      360826
#
#      Comment Count
# 0              268
# 1              519
# 2              491
# 3             1717
# 4              394
# ..             ...
# 537           1601
# 538            377
# 539           2411
# 540           2307
# 541           3251
#
# [500 rows x 4 columns]

# %%
_csv=api_df.to_csv (r'Posts.csv', index = None, header=True)

# %% [markdown]
# # Google Vision API

# %%
list_of_urls = api_df["URL"].tolist() #change test to api_df when ready

# %%
from google.cloud import vision
import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "keyFile.json"
image_urls = list_of_urls
ls_of_label_for_url = []

for url in image_urls:
    image_uri = url
    label_list = []
    client = vision.ImageAnnotatorClient()
    image = vision.types.Image()
    image.source.image_uri = image_uri
    response = client.label_detection(image=image)
    print('Labels (and confidence score):')
    print('=' * 79)
    
    for label in response.label_annotations:
        label_list.append(label.description)
        print(f'{label.description} ({label.score*100.:.2f}%)')
    ls_of_label_for_url.append(label_list)
    
print(ls_of_label_for_url)
print('Length of unedited list',len(ls_of_label_for_url))

ls_of_label_for_url = list(filter(None, ls_of_label_for_url))
print(ls_of_label_for_url)
print('Length of edited list', len(ls_of_label_for_url))
# Out:
# Labels (and confidence score):
# ===============================================================================
# Rays and skates (88.14%)
# Fish (82.69%)
# Underwater (81.39%)
# Water (80.73%)
# Manta ray (77.54%)
# Organism (76.72%)
# Marine biology (73.21%)
# Stingray (71.06%)
# Cartilaginous fish (61.89%)
# Skate (60.42%)
# Labels (and confidence score):
# ===============================================================================
# Photography (62.42%)
# Labels (and confidence score):
# ===============================================================================
# Badlands (98.23%)
# Mountainous landforms (98.08%)
# Sky (97.49%)
# Nature (95.35%)
# Mountain (93.90%)
# Rock (93.53%)
# Formation (91.75%)
# Cloud (91.28%)
# Wilderness (89.94%)
# Geology (88.88%)
# Labels (and confidence score):
# ===============================================================================
# Rock (69.81%)
# Tourism (69.71%)
# Landscape (59.31%)
# National park (54.88%)
# Labels (and confidence score):
# ===============================================================================
# People (95.68%)
# Community (84.84%)
# Yellow (83.63%)
# Tradition (76.61%)
# Event (76.34%)
# Temple (72.84%)
# Tourism (68.09%)
# Adaptation (66.97%)
# Sari (66.58%)
# Smile (64.11%)
# Labels (and confidence score):
# ===============================================================================
# Water (95.78%)
# Photograph (95.59%)
# Sky (94.83%)
# Sea (93.78%)
# Skin (90.60%)
# Beauty (90.38%)
# Ocean (87.65%)
# Vacation (86.62%)
# Summer (83.16%)
# Cloud (80.34%)
# Labels (and confidence score):
# ===============================================================================
# People in nature (97.89%)
# Grassland (92.74%)
# Natural landscape (88.55%)
# Standing (83.56%)
# Grass (82.18%)
# Grass family (80.26%)
# Ecoregion (74.21%)
# Sky (73.26%)
# Field (72.87%)
# Photography (70.60%)
# Labels (and confidence score):
# ===============================================================================
# Plumbing fixture (73.74%)
# Tile (67.61%)
# Plumbing (58.79%)
# Shower (53.46%)
# Labels (and confidence score):
# ===============================================================================
# Event (62.74%)
# Temple (61.13%)
# Labels (and confidence score):
# ===============================================================================
# Sky (97.35%)
# Nature (96.72%)
# Mountainous landforms (91.50%)
# Mountain (91.41%)
# Reflection (89.63%)
# Light (87.39%)
# Rock (87.27%)
# Atmospheric phenomenon (85.69%)
# Night (84.59%)
# Atmosphere (84.04%)
# Labels (and confidence score):
# ===============================================================================
# Temple (75.22%)
# Adaptation (66.97%)
# World (53.14%)
# Labels (and confidence score):
# ===============================================================================
# Sky (98.43%)
# Nature (96.55%)
# Water (95.78%)
# Green (94.08%)
# Natural landscape (93.98%)
# Cloud (93.82%)
# Horizon (92.17%)
# Sea (88.05%)
# Sound (84.97%)
# Water resources (84.60%)
# Labels (and confidence score):
# ===============================================================================
# Water (80.73%)
# Tree (79.89%)
# Landscape (65.04%)
# Night (62.84%)
# Geological phenomenon (61.63%)
# Watercourse (60.54%)
# Mountain (60.31%)
# Plant (58.55%)
# City (51.35%)
# Labels (and confidence score):
# ===============================================================================
# Water transportation (97.32%)
# Harbor (95.52%)
# Boat (94.93%)
# Vehicle (89.12%)
# Fishing vessel (88.82%)
# Port (88.18%)
# Transport (83.51%)
# Water (80.73%)
# Marina (79.45%)
# Watercraft (77.00%)
# Labels (and confidence score):
# ===============================================================================
# Lion (95.72%)
# Wildlife (94.98%)
# Masai lion (86.35%)
# Big cats (79.36%)
# Felidae (74.67%)
# Sky (73.26%)
# Tree (68.69%)
# Adaptation (66.97%)
# Landscape (65.04%)
# Savanna (64.08%)
# Labels (and confidence score):
# ===============================================================================
# Wilderness (86.62%)
# Tree (84.93%)
# Botany (82.20%)
# Soil (79.53%)
# Grass family (77.09%)
# Grass (76.20%)
# Plant (76.06%)
# Gardener (72.27%)
# Spring (71.86%)
# Garden (65.85%)
# Labels (and confidence score):
# ===============================================================================
# Tree (97.85%)
# Sky (96.77%)
# Blue (92.70%)
# Woody plant (87.83%)
# Plant (86.81%)
# Night (85.30%)
# Branch (83.71%)
# Trunk (76.56%)
# Electric blue (74.21%)
# Midnight (58.42%)
# Labels (and confidence score):
# ===============================================================================
# People in nature (97.89%)
# Photograph (96.56%)
# Black (95.12%)
# Black-and-white (89.52%)
# Photography (84.69%)
# Male (84.17%)
# Monochrome photography (81.97%)
# Rock (79.44%)
# Arm (77.59%)
# Human (75.91%)
# Labels (and confidence score):
# ===============================================================================
# Reflection (98.59%)
# Water (97.15%)
# Reflecting pool (90.93%)
# Architecture (76.33%)
# Symmetry (62.82%)
# River (53.56%)
# Water feature (51.03%)
# Labels (and confidence score):
# ===============================================================================
# Lady (91.43%)
# Beauty (91.17%)
# Lip (79.91%)
# Fashion (79.79%)
# Photo shoot (79.64%)
# Arm (77.59%)
# Shoulder (75.08%)
# Flash photography (73.58%)
# Model (72.53%)
# Photography (72.45%)
# Labels (and confidence score):
# ===============================================================================
# Visual effect lighting (83.43%)
# Technology (74.57%)
# Display device (71.28%)
# Electronic device (60.99%)
# Labels (and confidence score):
# ===============================================================================
# Tiger (99.48%)
# Wildlife (98.57%)
# Vertebrate (98.51%)
# Bengal tiger (98.03%)
# Siberian tiger (97.35%)
# Mammal (97.27%)
# Felidae (96.55%)
# Whiskers (91.25%)
# Water (91.00%)
# Terrestrial animal (90.82%)
# Labels (and confidence score):
# ===============================================================================
# Wave (95.45%)
# Ocean (89.51%)
# Surfing Equipment (87.78%)
# Surfing (87.21%)
# Sea (86.33%)
# Surfboard (83.87%)
# Coast (80.89%)
# Wind wave (80.39%)
# Boardsport (79.25%)
# Tide (75.87%)
# Labels (and confidence score):
# ===============================================================================
# Water (95.78%)
# Nature (95.35%)
# Black-and-white (94.43%)
# Atmospheric phenomenon (90.91%)
# Monochrome photography (90.83%)
# Monochrome (78.34%)
# Tree (77.84%)
# Rock (75.92%)
# Geological phenomenon (73.91%)
# Winter (73.76%)
# Labels (and confidence score):
# ===============================================================================
# Army (98.30%)
# Soldier (97.83%)
# Military (97.13%)
# Military uniform (95.40%)
# Troop (93.86%)
# Military organization (93.83%)
# Infantry (92.74%)
# Military person (91.17%)
# Marines (79.02%)
# Military camouflage (77.62%)
# Labels (and confidence score):
# ===============================================================================
# Arctic (91.44%)
# Glacial landform (89.96%)
# Natural environment (87.15%)
# Tundra (83.20%)
# Glacier (80.78%)
# Wildlife (78.65%)
# Snow (78.61%)
# Ice cap (78.20%)
# Mountain (77.51%)
# Arctic ocean (77.42%)
# Labels (and confidence score):
# ===============================================================================
# Face (98.43%)
# Facial expression (94.48%)
# Wrinkle (94.36%)
# Forehead (93.88%)
# Skin (93.26%)
# Head (91.90%)
# Chin (87.52%)
# Human (84.68%)
# Male (80.90%)
# Cheek (79.95%)
# Labels (and confidence score):
# ===============================================================================
# Design (73.01%)
# Textile (68.45%)
# Colorfulness (67.83%)
# Pattern (65.68%)
# Photography (62.42%)
# Crowd (50.70%)
# Labels (and confidence score):
# ===============================================================================
# Hair (98.69%)
# Face (97.95%)
# Beauty (92.50%)
# Lip (90.57%)
# Lady (89.53%)
# Hairstyle (89.53%)
# Smile (88.74%)
# Eyebrow (87.64%)
# Brown hair (85.71%)
# Chin (85.04%)
# Labels (and confidence score):
# ===============================================================================
# Mammal (98.90%)
# Hyena (98.78%)
# Vertebrate (98.51%)
# Wildlife (97.71%)
# Terrestrial animal (96.69%)
# Spotted hyena (94.62%)
# Carnivore (93.42%)
# Snout (73.43%)
# Savanna (56.52%)
# Felidae (54.08%)
# Labels (and confidence score):
# ===============================================================================
# Sky (97.19%)
# Nature (95.35%)
# Horizon (94.92%)
# Atmosphere (94.29%)
# Atmospheric phenomenon (94.22%)
# Freezing (91.54%)
# Light (89.30%)
# Winter (88.94%)
# Morning (88.02%)
# Evening (87.49%)
# Labels (and confidence score):
# ===============================================================================
# Night (53.94%)
# Labels (and confidence score):
# ===============================================================================
# Sky (97.45%)
# Water (95.13%)
# Blue (92.70%)
# Sea (85.70%)
# Atmosphere (84.04%)
# Cloud (83.81%)
# Ocean (83.12%)
# Horizon (70.93%)
# Rock (69.81%)
# Tree (68.69%)
# Labels (and confidence score):
# ===============================================================================
# Sky (99.05%)
# Cloud (98.27%)
# White (97.18%)
# Black (97.01%)
# Black-and-white (95.77%)
# Nature (95.50%)
# Monochrome photography (95.11%)
# Monochrome (93.93%)
# Water (91.00%)
# Natural landscape (88.55%)
# Labels (and confidence score):
# ===============================================================================
# Yellow (86.49%)
# Sky (82.21%)
# Sand (73.38%)
# Dune (66.73%)
# Landscape (65.04%)
# Heat (51.50%)
# Aeolian landform (51.19%)
# Labels (and confidence score):
# ===============================================================================
# Design (72.03%)
# Room (71.39%)
# Photography (70.60%)
# Material property (69.92%)
# Technology (67.58%)
# Architecture (65.45%)
# Black-and-white (56.41%)
# Collage (55.30%)
# Interior design (54.31%)
# Art (50.22%)
# Labels (and confidence score):
# ===============================================================================
# Room (82.12%)
# Photography (62.42%)
# Sitting (60.23%)
# Labels (and confidence score):
# ===============================================================================
# Art (50.22%)
# Labels (and confidence score):
# ===============================================================================
# People (95.89%)
# Green (94.52%)
# Product (93.48%)
# Social group (91.85%)
# Crowd (90.31%)
# Event (88.69%)
# Youth (87.85%)
# Cheering (87.06%)
# Performance (86.24%)
# Audience (84.42%)
# Labels (and confidence score):
# ===============================================================================
# Soldier (97.91%)
# Military organization (89.80%)
# Military (89.68%)
# Army (89.15%)
# Military camouflage (88.60%)
# Infantry (79.63%)
# Troop (77.18%)
# Design (73.01%)
# Marines (66.01%)
# Military uniform (57.23%)
# Labels (and confidence score):
# ===============================================================================
# Electricity (88.15%)
# Urban area (86.58%)
# Transport (86.29%)
# Mode of transport (83.94%)
# Town (82.34%)
# Sky (82.21%)
# Cooling tower (80.80%)
# Electrical supply (80.07%)
# Vehicle (78.61%)
# City (78.50%)
# Labels (and confidence score):
# ===============================================================================
# Night (89.20%)
# Tree (82.55%)
# Statue (78.29%)
# Sculpture (73.40%)
# Tourism (71.09%)
# City (68.61%)
# Tower (66.88%)
# Temple (66.23%)
# Town square (64.58%)
# Leisure (63.88%)
# Labels (and confidence score):
# ===============================================================================
# Mammal (98.90%)
# Vertebrate (98.51%)
# Dog (96.86%)
# Canidae (96.18%)
# Carnivore (93.42%)
# Dog breed (90.27%)
# Hunting dog (82.73%)
# Wildlife (78.65%)
# Sporting Group (73.25%)
# Labels (and confidence score):
# ===============================================================================
# Face (97.28%)
# Black (95.86%)
# Darkness (92.99%)
# Beauty (88.58%)
# Head (88.43%)
# Lady (87.16%)
# Portrait (87.05%)
# Nose (84.20%)
# Eye (80.49%)
# Flash photography (79.29%)
# Labels (and confidence score):
# ===============================================================================
# Sky (97.94%)
# Daytime (92.13%)
# Blue (91.18%)
# Cloud (84.67%)
# Atmosphere (84.04%)
# Azure (80.35%)
# Horizon (79.62%)
# Ice (73.57%)
# Calm (71.15%)
# Ice cap (69.17%)
# Labels (and confidence score):
# ===============================================================================
# Sky (93.36%)
# House (88.40%)
# Property (86.91%)
# Home (82.30%)
# Coast (82.06%)
# Sea (81.78%)
# Architecture (76.33%)
# Ocean (75.96%)
# Building (73.10%)
# Coastal and oceanic landforms (69.27%)
# Labels (and confidence score):
# ===============================================================================
# Yellow (91.82%)
# Rock (89.99%)
# Wood (80.42%)
# Formation (77.27%)
# Adventure (76.84%)
# Badlands (76.10%)
# Tree (74.70%)
# Extreme sport (71.96%)
# Climbing (70.73%)
# Cliff (66.07%)
# Labels (and confidence score):
# ===============================================================================
# Wildlife (96.52%)
# Elk (96.50%)
# Reindeer (95.87%)
# Antler (95.37%)
# Barren ground Caribou (94.12%)
# Deer (92.61%)
# Horn (86.48%)
# Morning (79.11%)
# Sky (73.26%)
# Organism (71.52%)
# Labels (and confidence score):
# ===============================================================================
# Sky (98.36%)
# Blue (95.78%)
# Cloud (91.05%)
# Horizon (89.67%)
# Sea (85.23%)
# Calm (79.60%)
# Ocean (75.14%)
# Landscape (71.56%)
# Beach (66.67%)
# Vacation (66.44%)
# Labels (and confidence score):
# ===============================================================================
# Skeleton (98.12%)
# Dinosaur (97.94%)
# Extinction (96.56%)
# Velociraptor (91.58%)
# Fossil (91.09%)
# Tyrannosaurus (90.97%)
# Museum (83.37%)
# Tourist attraction (61.75%)
# Jaw (57.41%)
# Labels (and confidence score):
# ===============================================================================
# Fin (89.42%)
# Marine mammal (82.73%)
# Sky (82.21%)
# Cetacea (73.88%)
# Fish (62.63%)
# Tail (52.64%)
# Labels (and confidence score):
# ===============================================================================
# Sky (96.85%)
# Night (92.49%)
# Volcanic landform (82.83%)
# Stratovolcano (79.74%)
# Geological phenomenon (73.91%)
# Hill (73.39%)
# Mountain (71.67%)
# Types of volcanic eruptions (68.54%)
# Landscape (68.08%)
# Volcano (67.75%)
# Labels (and confidence score):
# ===============================================================================
# Wildlife (97.36%)
# Savanna (91.14%)
# Herd (86.42%)
# Landscape (68.08%)
# Painting (63.85%)
# Safari (63.05%)
# Grazing (54.30%)
# Grassland (50.23%)
# Labels (and confidence score):
# ===============================================================================
# Sky (99.18%)
# Red sky at morning (95.36%)
# Sunset (93.99%)
# Afterglow (93.28%)
# Orange (93.04%)
# Cloud (92.06%)
# Sunrise (90.78%)
# Horizon (90.61%)
# Evening (90.57%)
# Red (90.19%)
# Labels (and confidence score):
# ===============================================================================
# Hair (97.71%)
# Hairstyle (85.96%)
# Long hair (69.10%)
# Headpiece (68.65%)
# Room (65.66%)
# Black hair (65.66%)
# Feather (50.94%)
# Costume (50.26%)
# Labels (and confidence score):
# ===============================================================================
# Horse (60.38%)
# Wildlife (57.62%)
# Labels (and confidence score):
# ===============================================================================
# Mountainous landforms (98.47%)
# Sky (98.38%)
# Blue (98.10%)
# Mountain (96.72%)
# Mountain range (96.09%)
# Atmospheric phenomenon (94.86%)
# Ridge (92.25%)
# Atmosphere (88.95%)
# Morning (88.31%)
# Cloud (87.26%)
# Labels (and confidence score):
# ===============================================================================
# Wall (89.66%)
# Horse (87.29%)
# Sky (82.21%)
# Snout (78.40%)
# Burro (76.73%)
# Livestock (73.16%)
# Wildlife (67.62%)
# Mane (67.59%)
# Wood (65.35%)
# Mare (59.75%)
# Labels (and confidence score):
# ===============================================================================
# Musical instrument (64.45%)
# Tradition (61.80%)
# Garmon (56.64%)
# Labels (and confidence score):
# ===============================================================================
# People (96.00%)
# Human (78.89%)
# Adaptation (74.08%)
# Smile (64.11%)
# Temple (63.72%)
# Event (62.74%)
# Child (61.35%)
# Art (58.13%)
# Crowd (57.81%)
# Flesh (53.55%)
# Labels (and confidence score):
# ===============================================================================
# Green (97.68%)
# Sky (88.58%)
# Aurora (80.47%)
# Grass (68.80%)
# Tree (68.69%)
# Landscape (68.08%)
# Grassland (57.75%)
# Night (57.54%)
# House (53.69%)
# Labels (and confidence score):
# ===============================================================================
# Blue (97.16%)
# Fish (87.12%)
# Fish (81.99%)
# Organism (81.17%)
# Water (80.73%)
# Marine biology (77.85%)
# Electric blue (58.19%)
# Hairfinned silverfish (54.38%)
# Deep sea fish (53.86%)
# Turquoise (51.21%)
# Labels (and confidence score):
# ===============================================================================
# Youth (82.32%)
# Community (81.46%)
# Event (69.43%)
# Adaptation (66.97%)
# Leisure (56.19%)
# Labels (and confidence score):
# ===============================================================================
# Furniture (87.46%)
# Room (80.06%)
# Bed (71.91%)
# Bedroom (67.48%)
# Textile (65.63%)
# Feather (60.27%)
# Bed sheet (55.40%)
# World (53.14%)
# Labels (and confidence score):
# ===============================================================================
# Wildlife (97.06%)
# Hyena (90.16%)
# Grassland (88.67%)
# Natural landscape (88.55%)
# Savanna (88.54%)
# Spotted hyena (88.37%)
# Safari (84.21%)
# Plain (78.23%)
# Lion (77.64%)
# Ecoregion (75.62%)
# Labels (and confidence score):
# ===============================================================================
# Snow (96.48%)
# Winter (95.78%)
# Bridge (91.46%)
# Trestle (84.69%)
# Freezing (83.59%)
# Water (80.73%)
# Wood (69.17%)
# Landscape (65.04%)
# Pier (64.72%)
# Mountain (54.44%)
# Labels (and confidence score):
# ===============================================================================
# Blue (98.02%)
# Sky (95.85%)
# Eyewear (88.57%)
# House (85.83%)
# Glasses (84.64%)
# Fun (82.20%)
# Winter (82.14%)
# Cloud (76.76%)
# Mountain (73.80%)
# Home (68.23%)
# Labels (and confidence score):
# ===============================================================================
# Yellow (83.63%)
# Watercolor paint (73.25%)
# Art (67.73%)
# Visual arts (64.93%)
# Paint (55.47%)
# Painting (53.36%)
# Illustration (50.41%)
# Labels (and confidence score):
# ===============================================================================
# Child (86.28%)
# Adaptation (81.25%)
# Photography (62.42%)
# Sitting (57.49%)
# Tribe (56.67%)
# Smile (54.04%)
# Art (50.22%)
# Labels (and confidence score):
# ===============================================================================
# Loggerhead sea turtle (98.05%)
# Sea turtle (97.95%)
# Green sea turtle (96.58%)
# Olive ridley sea turtle (92.82%)
# Turtle (91.84%)
# Hawksbill sea turtle (90.10%)
# Kemp's ridley sea turtle (89.94%)
# Wave (71.19%)
# Reptile (67.36%)
# Sea (56.08%)
# Labels (and confidence score):
# ===============================================================================
# People (96.30%)
# Child (86.59%)
# Adaptation (74.08%)
# Smile (64.11%)
# Play (57.26%)
# Tourism (56.89%)
# Travel (51.82%)
# Labels (and confidence score):
# ===============================================================================
# Garden (92.93%)
# Natural landscape (88.55%)
# Tree (87.87%)
# Botany (85.79%)
# Pond (84.18%)
# Spring (83.93%)
# Botanical garden (81.30%)
# Plant (78.31%)
# Grass family (77.09%)
# Leaf (75.95%)
# Labels (and confidence score):
# ===============================================================================
# Tourism (78.42%)
# Ancient history (77.89%)
# Landscape (71.56%)
# Rock (69.81%)
# Historic site (63.14%)
# Travel (62.47%)
# Temple (61.13%)
# History (54.11%)
# Unesco world heritage site (52.74%)
# Archaeological site (52.42%)
# Labels (and confidence score):
# ===============================================================================
# Road (96.19%)
# Sky (96.14%)
# Nature (95.35%)
# Cycling (93.65%)
# Vegetation (90.37%)
# Atmospheric phenomenon (88.61%)
# Tree (87.57%)
# Bicycle (87.31%)
# Asphalt (87.21%)
# Dirt road (86.99%)
# Labels (and confidence score):
# ===============================================================================
# People (97.58%)
# Child (92.01%)
# Social group (90.02%)
# Community (87.32%)
# Adaptation (80.36%)
# Tourism (56.89%)
# Smile (54.04%)
# Family (53.12%)
# Village (52.73%)
# Labels (and confidence score):
# ===============================================================================
# Underwater (98.48%)
# Reef (95.13%)
# Marine biology (93.57%)
# Water (91.00%)
# Organism (89.90%)
# Natural environment (89.35%)
# Scuba diving (89.24%)
# Coral reef (88.78%)
# Coral (87.50%)
# Diving equipment (85.05%)
# Labels (and confidence score):
# ===============================================================================
# Adaptation (86.35%)
# Tribe (83.43%)
# Temple (62.56%)
# Smile (54.04%)
# Child (52.03%)
# Labels (and confidence score):
# ===============================================================================
# Blue (97.06%)
# Sky (96.68%)
# Water (95.13%)
# Horizon (94.97%)
# Sea (94.79%)
# Ocean (86.11%)
# Atmospheric phenomenon (85.69%)
# Pier (84.57%)
# Calm (80.17%)
# Beach (74.11%)
# Labels (and confidence score):
# ===============================================================================
# Human (74.68%)
# Sitting (68.87%)
# Conversation (66.36%)
# Room (65.66%)
# Event (62.74%)
# House (59.29%)
# Plant (58.55%)
# Window (53.80%)
# Tourism (51.14%)
# Labels (and confidence score):
# ===============================================================================
# Python (88.47%)
# Reptile (80.97%)
# Hand (80.95%)
# Python family (78.35%)
# Serpent (76.13%)
# Hognose snake (75.34%)
# Scaled reptile (72.28%)
# Burmese python (66.67%)
# Snake (62.98%)
# Labels (and confidence score):
# ===============================================================================
# Fur (97.83%)
# Fur clothing (89.85%)
# Facial hair (84.90%)
# Beard (80.53%)
# Human (77.66%)
# Cap (77.06%)
# Headgear (76.06%)
# Ushanka (70.57%)
# Textile (70.36%)
# Portrait (61.52%)
# Labels (and confidence score):
# ===============================================================================
# Reptile (95.40%)
# Scaled reptile (86.74%)
# Snake (80.77%)
# Organism (76.72%)
# Terrestrial animal (74.44%)
# Adaptation (66.97%)
# Elapidae (66.27%)
# Serpent (64.70%)
# Beak (62.77%)
# Macro photography (58.22%)
# Labels (and confidence score):
# ===============================================================================
# Soil (78.01%)
# Rock (73.36%)
# Geology (67.97%)
# Sand (59.90%)
# Wood (59.59%)
# Beige (54.84%)
# Flooring (53.95%)
# Floor (53.89%)
# Labels (and confidence score):
# ===============================================================================
# Blue (96.67%)
# Portrait (87.05%)
# Water (80.73%)
# Photography (77.53%)
# Eye (75.86%)
# Human (74.68%)
# Sky (73.26%)
# Reflection (68.89%)
# Hand (66.00%)
# Jaw (63.02%)
# Labels (and confidence score):
# ===============================================================================
# Sky (94.83%)
# Purple (91.31%)
# Pink (91.24%)
# Architecture (90.47%)
# Light (88.35%)
# Landmark (87.77%)
# Lighting (81.84%)
# Line (79.85%)
# Symmetry (76.10%)
# Urban area (74.97%)
# Labels (and confidence score):
# ===============================================================================
# People (94.80%)
# Fun (70.39%)
# Temple (63.72%)
# Smile (54.04%)
# Labels (and confidence score):
# ===============================================================================
# Amphibian (84.85%)
# Frog (80.90%)
# Poison dart frog (77.08%)
# Organism (76.72%)
# Fungus (64.83%)
# Wildlife (57.62%)
# Fawn (53.01%)
# Phyllobates (51.43%)
# Toad (51.15%)
# Labels (and confidence score):
# ===============================================================================
# Jungle (94.13%)
# Natural environment (91.74%)
# Tree (86.87%)
# Rainforest (86.57%)
# Forest (85.34%)
# Nature reserve (83.42%)
# Adaptation (80.36%)
# Botany (78.69%)
# Wildlife (76.23%)
# Plant (74.28%)
# Labels (and confidence score):
# ===============================================================================
# Fun (70.39%)
# Sitting (68.87%)
# Leisure (56.19%)
# Furniture (53.32%)
# Chair (51.26%)
# Labels (and confidence score):
# ===============================================================================
# Polar ice cap (97.41%)
# Ice (95.53%)
# Sky (93.82%)
# Arctic (93.76%)
# Iceberg (92.82%)
# Sea ice (92.28%)
# Arctic ocean (92.03%)
# Atmospheric phenomenon (92.01%)
# Ocean (91.80%)
# Natural environment (90.59%)
# Labels (and confidence score):
# ===============================================================================
# Table (90.91%)
# Room (86.48%)
# Furniture (78.62%)
# Interior design (77.19%)
# Restaurant (75.80%)
# Vacation (75.20%)
# Leisure (70.92%)
# Coffee table (67.34%)
# House (59.29%)
# Wallpaper (54.56%)
# Labels (and confidence score):
# ===============================================================================
# Mountainous landforms (99.02%)
# Mountain (98.36%)
# Mountain range (93.41%)
# Ridge (90.62%)
# Sky (88.58%)
# Summit (84.65%)
# Geological phenomenon (79.50%)
# Massif (76.36%)
# Fell (75.14%)
# Highland (74.05%)
# Labels (and confidence score):
# ===============================================================================
# Hair (98.84%)
# Face (98.54%)
# Facial expression (94.44%)
# Chin (92.41%)
# Hairstyle (91.19%)
# Head (90.14%)
# Eyebrow (89.94%)
# Nose (86.99%)
# Beauty (86.39%)
# Blond (84.73%)
# Labels (and confidence score):
# ===============================================================================
# Architecture (95.10%)
# Sky (94.21%)
# Reflection (89.89%)
# Building (83.93%)
# Mixed-use (83.41%)
# Night (78.51%)
# Urban area (74.97%)
# Facade (72.49%)
# House (71.72%)
# Real estate (67.23%)
# Labels (and confidence score):
# ===============================================================================
# Metropolitan area (97.85%)
# Cityscape (97.50%)
# Urban area (97.35%)
# Metropolis (97.25%)
# City (96.79%)
# Night (92.62%)
# Human settlement (91.55%)
# Landmark (90.14%)
# Architecture (88.84%)
# Town (83.48%)
# Labels (and confidence score):
# ===============================================================================
# Grassland (82.11%)
# Rock (79.44%)
# Ecoregion (77.64%)
# Pasture (76.98%)
# Grass (76.20%)
# Hill (75.14%)
# Rural area (71.17%)
# Working animal (69.03%)
# Horse (67.90%)
# Steppe (64.25%)
# Labels (and confidence score):
# ===============================================================================
# Yellow (91.82%)
# Water (91.00%)
# Elephant (86.43%)
# Elephants and Mammoths (80.01%)
# Wildlife (72.86%)
# Organism (71.52%)
# African elephant (67.97%)
# Wave (67.40%)
# Labels (and confidence score):
# ===============================================================================
# Bird (99.60%)
# Vertebrate (98.51%)
# Beak (98.33%)
# Seabird (71.23%)
# Stork (65.82%)
# Ciconiiformes (60.37%)
# Water bird (55.88%)
# Feather (50.94%)
# Labels (and confidence score):
# ===============================================================================
# Formation (91.00%)
# Rock (89.57%)
# Fault (84.27%)
# Badlands (84.22%)
# Geology (84.12%)
# Geological phenomenon (82.74%)
# Bedrock (67.52%)
# Dike (66.89%)
# Outcrop (64.30%)
# Intrusion (63.12%)
# Labels (and confidence score):
# ===============================================================================
# Mountainous landforms (97.92%)
# Mountain (97.04%)
# White (96.29%)
# Black (95.72%)
# Atmospheric phenomenon (95.26%)
# Mist (94.63%)
# Sky (93.82%)
# Black-and-white (91.53%)
# Fog (89.18%)
# Mountain range (88.69%)
# Labels (and confidence score):
# ===============================================================================
# Natural landscape (98.26%)
# Body of water (98.23%)
# Nature (97.80%)
# Vegetation (97.59%)
# Nature reserve (97.10%)
# Water (96.18%)
# Natural environment (95.80%)
# Water resources (94.95%)
# Watercourse (94.87%)
# Forest (94.62%)
# Labels (and confidence score):
# ===============================================================================
# Fish (97.70%)
# Requiem shark (97.30%)
# Shark (97.18%)
# Tiger shark (95.87%)
# Carcharhiniformes (95.74%)
# Great white shark (95.56%)
# Underwater (95.51%)
# Marine biology (95.02%)
# Bull shark (94.84%)
# Cartilaginous fish (94.54%)
# Labels (and confidence score):
# ===============================================================================
# Tree (96.94%)
# Palm tree (91.82%)
# Arecales (86.81%)
# Woody plant (84.88%)
# Plant (82.58%)
# Date palm (81.40%)
# Adaptation (74.08%)
# House (66.01%)
# Architecture (65.45%)
# Landscape (65.04%)
# Labels (and confidence score):
# ===============================================================================
# Blond (85.32%)
# Shoulder (80.13%)
# Grass (79.87%)
# Joint (73.96%)
# Neck (73.72%)
# Photography (67.79%)
# Leisure (56.19%)
# Smile (54.04%)
# Grassland (50.23%)
# Sleeve (50.02%)
# Labels (and confidence score):
# ===============================================================================
# Violet (80.70%)
# Headgear (67.48%)
# Labels (and confidence score):
# ===============================================================================
# Facial hair (84.90%)
# Beard (77.95%)
# Human (77.66%)
# Hand (77.60%)
# Arm (77.59%)
# Night (68.17%)
# Photography (67.79%)
# Room (65.66%)
# Gesture (62.35%)
# Flesh (60.60%)
# Labels (and confidence score):
# ===============================================================================
# Skateboarding (96.42%)
# Skateboard (93.64%)
# Boardsport (90.89%)
# Skateboarding Equipment (87.92%)
# Recreation (85.07%)
# Skateboarder (84.68%)
# Sky (82.21%)
# Skatepark (78.81%)
# Jumping (78.77%)
# Extreme sport (75.31%)
# Labels (and confidence score):
# ===============================================================================
# Eyewear (99.40%)
# Cool (93.76%)
# Glasses (93.14%)
# Sunglasses (92.98%)
# Lip (88.13%)
# Fun (83.70%)
# Personal protective equipment (83.23%)
# Fashion (78.86%)
# Vision care (78.53%)
# Hand (69.69%)
# Labels (and confidence score):
# ===============================================================================
# Hair (97.31%)
# Tree (84.93%)
# Grass (82.18%)
# Long hair (73.61%)
# Photography (70.60%)
# Plant (62.44%)
# Rope (60.24%)
# Cloud (59.49%)
# Grassland (50.23%)
# Labels (and confidence score):
# ===============================================================================
# Soldier (99.07%)
# Military (95.60%)
# Army (95.25%)
# Infantry (92.74%)
# Military organization (90.57%)
# Military camouflage (89.30%)
# Military uniform (89.22%)
# Troop (81.87%)
# Airsoft (78.48%)
# Marines (76.01%)
# Labels (and confidence score):
# ===============================================================================
# Vehicle (91.64%)
# Head restraint (87.09%)
# Car (85.88%)
# Driving (84.71%)
# Automotive design (72.28%)
# Family car (69.77%)
# Photography (62.42%)
# Auto part (61.18%)
# Mid-size car (58.50%)
# Compact car (56.30%)
# Labels (and confidence score):
# ===============================================================================
# Horse (92.59%)
# Rein (83.22%)
# Mane (68.15%)
# Stock photography (62.05%)
# Labels (and confidence score):
# ===============================================================================
# Product (88.28%)
# Fun (82.20%)
# Public space (80.73%)
# Community (79.56%)
# Leisure (78.88%)
# Technology (74.57%)
# Child (69.31%)
# Games (69.03%)
# Recreation (68.78%)
# Vehicle (64.41%)
# Labels (and confidence score):
# ===============================================================================
# Grass (92.86%)
# Cheerleading (86.50%)
# Fun (76.85%)
# Photography (62.42%)
# Team (59.35%)
# Plant (58.55%)
# Brown hair (57.83%)
# Leisure (56.19%)
# Team sport (55.82%)
# Sport venue (54.19%)
# Labels (and confidence score):
# ===============================================================================
# Food (57.37%)
# Smile (54.04%)
# Cuisine (53.68%)
# Labels (and confidence score):
# ===============================================================================
# Umbrella (93.74%)
# Headgear (71.12%)
# Fashion accessory (67.37%)
# Tourism (56.89%)
# Labels (and confidence score):
# ===============================================================================
# Photograph (94.98%)
# Sitting (90.12%)
# Skin (85.93%)
# Fashion (82.37%)
# Human (77.66%)
# Fun (76.85%)
# Leg (76.07%)
# Room (74.44%)
# Photography (67.79%)
# Conversation (67.00%)
# Labels (and confidence score):
# ===============================================================================
# Red (96.03%)
# Heat (92.22%)
# Light (89.75%)
# Darkness (84.65%)
# Lighting (82.36%)
# Fire (74.44%)
# Flame (73.33%)
# Room (65.66%)
# Flare (63.79%)
# Event (62.74%)
# Labels (and confidence score):
# ===============================================================================
# Sitting (92.58%)
# Blond (88.02%)
# Lady (85.50%)
# Fashion (78.86%)
# Outerwear (76.05%)
# Photography (72.45%)
# Leg (69.20%)
# Tree (68.69%)
# Long hair (64.64%)
# Plant (58.55%)
# Labels (and confidence score):
# ===============================================================================
# Crowd (80.51%)
# Sports (73.16%)
# Footwear (72.95%)
# Street performance (72.06%)
# Leisure (68.10%)
# Sport venue (66.30%)
# Event (62.74%)
# Dance (56.37%)
# Basketball (56.28%)
# Performance (50.90%)
# Labels (and confidence score):
# ===============================================================================
# Dress (95.08%)
# Pink (94.59%)
# Lady (93.12%)
# Clothing (92.83%)
# Beauty (89.61%)
# Gown (88.62%)
# Skin (88.11%)
# Shoulder (87.33%)
# Bride (83.73%)
# Wedding dress (82.87%)
# Labels (and confidence score):
# ===============================================================================
# Sky (98.65%)
# Blue (91.18%)
# Cloud (82.83%)
# Horizon (80.53%)
# Silhouette (77.29%)
# Sea (74.93%)
# Atmosphere (72.90%)
# Calm (71.15%)
# Astronomical object (70.91%)
# Evening (70.39%)
# Labels (and confidence score):
# ===============================================================================
# Aurora (98.85%)
# Sky (98.23%)
# Nature (97.20%)
# Green (97.05%)
# Atmospheric phenomenon (91.25%)
# Natural landscape (88.55%)
# Atmosphere (88.41%)
# Geological phenomenon (84.87%)
# Landscape (74.41%)
# Night (72.85%)
# Labels (and confidence score):
# ===============================================================================
# Parka (87.87%)
# Winter (87.08%)
# Outerwear (79.78%)
# Snow (79.77%)
# Coat (78.51%)
# Fur (69.13%)
# Headgear (67.48%)
# Jacket (64.51%)
# Photography (62.42%)
# Shotgun (56.83%)
# Labels (and confidence score):
# ===============================================================================
# Darkness (88.70%)
# Lady (86.41%)
# Smoke (78.68%)
# Human (74.68%)
# Human body (71.52%)
# Hand (66.00%)
# Performance art (60.58%)
# Flesh (57.73%)
# Portrait (51.59%)
# Performance (50.90%)
# Labels (and confidence score):
# ===============================================================================
# Street (82.61%)
# Alley (76.66%)
# Building (75.54%)
# Infrastructure (74.22%)
# Road (71.34%)
# Door (66.28%)
# Architecture (65.45%)
# Facade (52.63%)
# Art (50.22%)
# Labels (and confidence score):
# ===============================================================================
# Sky (98.09%)
# Night (95.72%)
# Blue (92.70%)
# Green (90.68%)
# Light (89.30%)
# Tree (86.01%)
# Lighting (81.84%)
# Water (80.73%)
# Atmosphere (80.43%)
# Cloud (76.76%)
# Labels (and confidence score):
# ===============================================================================
# Wall (90.05%)
# Street art (88.39%)
# Art (85.11%)
# Poster (76.33%)
# Mural (73.28%)
# Graffiti (63.80%)
# Advertising (53.03%)
# Labels (and confidence score):
# ===============================================================================
# People (94.50%)
# Adaptation (79.12%)
# Event (62.74%)
# Tribe (60.90%)
# Crowd (50.70%)
# Labels (and confidence score):
# ===============================================================================
# People (95.36%)
# Red (90.19%)
# Child (81.40%)
# Fun (76.85%)
# Adaptation (74.08%)
# Room (65.66%)
# Leisure (63.88%)
# Event (62.74%)
# Photography (62.42%)
# Vacation (54.60%)
# Labels (and confidence score):
# ===============================================================================
# People (93.70%)
# Water (91.00%)
# Jumping (88.86%)
# Fun (86.50%)
# Child (84.02%)
# Human (74.68%)
# Happy (72.59%)
# Play (69.64%)
# Adaptation (66.97%)
# Photography (62.42%)
# Labels (and confidence score):
# ===============================================================================
# Vertebrate (98.51%)
# Bird (98.37%)
# Macaw (98.09%)
# Parrot (94.51%)
# Beak (89.26%)
# Adaptation (79.12%)
# Wing (77.76%)
# Organism (76.72%)
# Lovebird (66.05%)
# Budgie (62.84%)
# Labels (and confidence score):
# ===============================================================================
# Sky (99.32%)
# Cloud (99.05%)
# Daytime (95.18%)
# Atmosphere (95.18%)
# Cumulus (94.37%)
# Atmospheric phenomenon (93.08%)
# Geological phenomenon (92.92%)
# Evening (89.29%)
# Meteorological phenomenon (84.47%)
# Orange (81.77%)
# Labels (and confidence score):
# ===============================================================================
# People (93.70%)
# Event (76.34%)
# Tradition (69.22%)
# Ritual (68.17%)
# Temple (67.44%)
# Ceremony (50.85%)
# Labels (and confidence score):
# ===============================================================================
# Leg (88.75%)
# Thigh (77.69%)
# Joint (73.96%)
# Muscle (67.94%)
# Knee (56.29%)
# Human leg (54.04%)
# Hip (50.67%)
# Labels (and confidence score):
# ===============================================================================
# Tourism (88.01%)
# Tree (87.23%)
# Community (85.46%)
# Crowd (85.22%)
# Hill station (74.84%)
# Leisure (73.01%)
# Summer (71.48%)
# Travel (71.26%)
# Fun (70.39%)
# Plant (67.32%)
# Labels (and confidence score):
# ===============================================================================
# Seal (98.45%)
# Mammal (97.06%)
# Harbor seal (96.94%)
# Fur seal (93.88%)
# Arctic (93.67%)
# Marine mammal (92.46%)
# Natural environment (91.41%)
# Steller sea lion (88.30%)
# Earless seal (85.14%)
# Ice (80.24%)
# Labels (and confidence score):
# ===============================================================================
# Fur clothing (95.56%)
# Fur (95.53%)
# Interaction (74.33%)
# Fun (70.39%)
# Love (63.12%)
# Photography (62.42%)
# Hug (55.99%)
# Happy (54.13%)
# Smile (54.04%)
# Gesture (51.73%)
# Labels (and confidence score):
# ===============================================================================
# Tunnel (98.05%)
# Darkness (93.65%)
# Infrastructure (80.36%)
# Tree (68.69%)
# Lava tube (63.92%)
# Geological phenomenon (61.63%)
# Formation (58.58%)
# Thoroughfare (57.66%)
# Cave (57.18%)
# Caving (52.67%)
# Labels (and confidence score):
# ===============================================================================
# Sitting (73.72%)
# Photography (62.42%)
# Labels (and confidence score):
# ===============================================================================
# Clothing (92.05%)
# Dress shirt (88.54%)
# Sleeve (83.54%)
# Shirt (78.65%)
# Formal wear (68.06%)
# Neck (65.36%)
# Gentleman (65.10%)
# Top (56.85%)
# Silk (53.98%)
# Labels (and confidence score):
# ===============================================================================
# Bicycle (98.36%)
# Pink (96.99%)
# Bicycle wheel (96.26%)
# Vehicle (94.69%)
# Cycling (91.35%)
# Bicycle drivetrain part (87.47%)
# Snapshot (82.92%)
# Mode of transport (80.82%)
# Recreation (79.06%)
# Sports equipment (78.12%)
# Labels (and confidence score):
# ===============================================================================
# Tunnel (96.26%)
# Light (87.39%)
# Infrastructure (84.15%)
# Road (81.15%)
# Thoroughfare (74.65%)
# Night (68.17%)
# Subway (67.60%)
# Ceiling (66.24%)
# Architecture (65.45%)
# Labels (and confidence score):
# ===============================================================================
# Wildlife (98.12%)
# Lion (96.68%)
# Sky (93.36%)
# Masai lion (87.83%)
# Felidae (86.26%)
# Big cats (85.30%)
# Grassland (84.61%)
# Wilderness (83.00%)
# Safari (76.55%)
# Plain (76.44%)
# Labels (and confidence score):
# ===============================================================================
# Elephant (99.64%)
# Elephants and Mammoths (99.30%)
# Terrestrial animal (99.20%)
# Vertebrate (98.51%)
# Wildlife (98.47%)
# African elephant (96.76%)
# Indian elephant (96.41%)
# Nature reserve (92.05%)
# Wilderness (89.23%)
# Natural landscape (88.55%)
# Labels (and confidence score):
# ===============================================================================
# Bird's-eye view (89.02%)
# Aerial photography (88.40%)
# Terrace (87.09%)
# Landscape (85.97%)
# Geology (74.52%)
# Field (65.27%)
# Terrain (62.48%)
# Stock photography (59.44%)
# Plain (57.83%)
# Labels (and confidence score):
# ===============================================================================
# People (93.70%)
# Holy places (90.03%)
# Wall (88.73%)
# Arch (80.62%)
# Ancient history (80.26%)
# Historic site (78.61%)
# Tourism (78.42%)
# Architecture (76.33%)
# Temple (72.84%)
# History (71.78%)
# Labels (and confidence score):
# ===============================================================================
# Water (91.00%)
# Wildlife (90.53%)
# Safari (69.52%)
# Canidae (67.40%)
# Bank (65.94%)
# Water bird (65.35%)
# Reflection (62.91%)
# Hunting dog (61.54%)
# Watercourse (60.54%)
# Pond (56.46%)
# Labels (and confidence score):
# ===============================================================================
# Farm (89.02%)
# Field (86.90%)
# Harvest (86.58%)
# Vehicle (75.64%)
# Rural area (75.30%)
# Grass family (73.99%)
# Sky (73.26%)
# Harvester (72.23%)
# Crop (66.72%)
# Plant (66.16%)
# Labels (and confidence score):
# ===============================================================================
# Patient (87.75%)
# Hospital (86.93%)
# Room (65.66%)
# Dressmaker (63.27%)
# Birth (61.36%)
# Knitting (57.18%)
# Service (52.84%)
# Clinic (52.53%)
# Hospital bed (52.26%)
# Operating theater (51.28%)
# Labels (and confidence score):
# ===============================================================================
# Skin (89.56%)
# Yellow (86.49%)
# Lady (84.34%)
# Human (80.55%)
# Happy (67.89%)
# Grandparent (67.63%)
# Photography (62.42%)
# Portrait (58.03%)
# Smile (54.04%)
# Art (50.22%)
# Labels (and confidence score):
# ===============================================================================
# Dog (99.54%)
# Mammal (98.90%)
# Vertebrate (98.51%)
# Dog breed (98.38%)
# Canidae (98.14%)
# Carnivore (93.42%)
# Beagle (92.98%)
# Harrier (89.99%)
# American foxhound (89.83%)
# Snout (87.77%)
# Labels (and confidence score):
# ===============================================================================
# Dog (99.54%)
# Vertebrate (98.51%)
# Dog breed (98.38%)
# Canidae (98.14%)
# Mammal (97.58%)
# Carnivore (85.47%)
# Snout (84.55%)
# Great dane (77.11%)
# Sporting Group (72.84%)
# Whiskers (70.57%)
# Labels (and confidence score):
# ===============================================================================
# Dog breed (98.38%)
# Dog (98.33%)
# Canidae (97.40%)
# Nose (84.20%)
# Snout (83.67%)
# Carnivore (83.66%)
# Austrian pinscher (76.81%)
# Sporting Group (75.52%)
# Whiskers (71.97%)
# Rare breed (dog) (61.31%)
# Labels (and confidence score):
# ===============================================================================
# Dog (99.54%)
# Canidae (98.14%)
# Mammal (97.58%)
# Dog breed (97.22%)
# Schnoodle (90.10%)
# Morkie (85.91%)
# Snout (85.85%)
# Puppy (85.70%)
# Carnivore (85.47%)
# Companion dog (80.39%)
# Labels (and confidence score):
# ===============================================================================
# Dog (99.54%)
# Mammal (98.90%)
# Vertebrate (98.51%)
# Canidae (98.14%)
# Dog breed (96.83%)
# Carnivore (93.42%)
# Alaunt (81.98%)
# Perro de presa canario (80.46%)
# Snout (78.40%)
# Cane corso (76.98%)
# Labels (and confidence score):
# ===============================================================================
# Dog (99.54%)
# Mammal (98.90%)
# Vertebrate (98.51%)
# Dog breed (98.38%)
# Canidae (98.14%)
# American pit bull terrier (91.73%)
# Bull and terrier (89.04%)
# Cordoba fighting dog (88.89%)
# American staffordshire terrier (87.76%)
# Snout (85.85%)
# Labels (and confidence score):
# ===============================================================================
# Sky (98.17%)
# Night (93.79%)
# Light (88.35%)
# Tree (85.50%)
# Cloud (82.83%)
# Lighting (81.25%)
# Evening (81.15%)
# Automotive exterior (78.11%)
# Automotive lighting (72.70%)
# Architecture (72.63%)
# Labels (and confidence score):
# ===============================================================================
# Fun (70.39%)
# Leg (69.20%)
# Muscle (64.24%)
# Games (52.12%)
# Labels (and confidence score):
# ===============================================================================
# Grass (88.55%)
# Rock (86.45%)
# Tree (81.39%)
# Water (80.73%)
# Grass family (77.09%)
# Plant (72.39%)
# Branch (70.11%)
# Snow (68.06%)
# Winter (61.88%)
# Labels (and confidence score):
# ===============================================================================
# Camel (99.05%)
# Arabian camel (97.26%)
# Desert (95.42%)
# Natural environment (94.63%)
# Camelid (91.32%)
# Sky (91.27%)
# Aeolian landform (87.34%)
# Landscape (84.51%)
# Ecoregion (84.44%)
# Sahara (81.66%)
# Labels (and confidence score):
# ===============================================================================
# Underwater (94.52%)
# Water (80.73%)
# Recreation (74.15%)
# Fun (70.39%)
# Underwater diving (64.44%)
# Sea (63.57%)
# Vacation (60.00%)
# Labels (and confidence score):
# ===============================================================================
# Bird (96.56%)
# Beak (87.46%)
# Ciconiiformes (82.95%)
# Stork (82.33%)
# Pelican (78.62%)
# Seabird (73.56%)
# Wildlife (67.62%)
# Adaptation (66.97%)
# Photography (62.42%)
# Pollution (58.71%)
# Labels (and confidence score):
# ===============================================================================
# Social group (90.69%)
# Uniform (84.05%)
# Event (81.89%)
# Male (80.90%)
# Ceremony (69.96%)
# Team (67.69%)
# Tradition (66.04%)
# Photography (62.42%)
# Labels (and confidence score):
# ===============================================================================
# Horse harness (97.94%)
# Horse (97.54%)
# Horse and buggy (96.36%)
# Mode of transport (92.83%)
# Carriage (90.47%)
# Cart (86.78%)
# Vehicle (86.50%)
# Pack animal (85.20%)
# Rein (84.69%)
# Wagon (84.61%)
# Labels (and confidence score):
# ===============================================================================
# Games (63.13%)
# Metal (51.15%)
# Labels (and confidence score):
# ===============================================================================
# Vertebrate (98.51%)
# Three-toed sloth (94.70%)
# Terrestrial animal (83.19%)
# Sloth (82.78%)
# Wildlife (81.94%)
# Branch (79.34%)
# Leaf (75.95%)
# Tree (68.69%)
# Plant (66.16%)
# Jungle (53.84%)
# Labels (and confidence score):
# ===============================================================================
# Camel (99.13%)
# Camelid (96.36%)
# Bovine (80.48%)
# Livestock (77.30%)
# Arabian camel (70.97%)
# Bull (67.69%)
# Event (62.74%)
# Tradition (55.84%)
# Ritual (53.69%)
# Labels (and confidence score):
# ===============================================================================
# Blue (91.18%)
# Tree (77.84%)
# Geological phenomenon (73.91%)
# Rock (64.38%)
# Formation (64.36%)
# Wood (59.59%)
# Plant (58.55%)
# World (53.14%)
# Art (50.22%)
# Labels (and confidence score):
# ===============================================================================
# Eating (78.19%)
# Human (74.68%)
# Food (69.83%)
# Meal (65.47%)
# Dish (56.52%)
# Child (52.03%)
# Comfort food (51.47%)
# Conversation (50.64%)
# Cuisine (50.45%)
# Labels (and confidence score):
# ===============================================================================
# Body of water (97.77%)
# Reflection (96.61%)
# Nature (95.76%)
# Blue (94.45%)
# Natural landscape (93.98%)
# Lake (91.59%)
# Sky (91.27%)
# Tarn (91.13%)
# Water (91.00%)
# Wilderness (89.23%)
# Labels (and confidence score):
# ===============================================================================
# Water (91.00%)
# Lady (85.50%)
# Human (78.32%)
# Photography (74.85%)
# Dress (74.80%)
# Muscle (67.94%)
# Happy (66.21%)
# Visual arts (62.48%)
# Sea (60.35%)
# Cloud (59.49%)
# Labels (and confidence score):
# ===============================================================================
# Living room (98.65%)
# Room (96.67%)
# Property (95.06%)
# Furniture (93.91%)
# Interior design (93.72%)
# Home (91.18%)
# Ceiling (88.43%)
# Real estate (86.01%)
# Building (83.49%)
# House (83.46%)
# Labels (and confidence score):
# ===============================================================================
# Highland (98.80%)
# Sky (98.38%)
# Mountainous landforms (97.02%)
# Mountain (96.59%)
# Nature (96.21%)
# Blue (94.45%)
# Cloud (94.29%)
# Hill (92.88%)
# Fell (92.75%)
# Lake (92.00%)
# Labels (and confidence score):
# ===============================================================================
# Water transportation (98.41%)
# Boat (94.61%)
# Mode of transport (92.39%)
# River (91.08%)
# Waterway (89.74%)
# Vehicle (89.47%)
# Morning (86.00%)
# Transport (85.13%)
# Harbor (83.99%)
# Town (82.94%)
# Labels (and confidence score):
# ===============================================================================
# Darkness (72.60%)
# Fiction (72.53%)
# Stock photography (63.96%)
# Fictional character (58.60%)
# Art (58.13%)
# Visual arts (55.03%)
# Labels (and confidence score):
# ===============================================================================
# Field (96.46%)
# Crop (94.61%)
# Agriculture (93.06%)
# Plantation (90.12%)
# Farm (89.33%)
# Cash crop (85.74%)
# Sky (82.21%)
# Morning (81.41%)
# Plant (76.98%)
# Rural area (71.17%)
# Labels (and confidence score):
# ===============================================================================
# Mammal (98.90%)
# Vertebrate (98.51%)
# Ferret (97.56%)
# Weasel (96.00%)
# Stoat (95.54%)
# polecat (91.06%)
# Black-footed ferret (88.16%)
# Mustelidae (85.54%)
# Mustelinae (84.48%)
# Whiskers (82.71%)
# Labels (and confidence score):
# ===============================================================================
# Stairs (87.27%)
# Design (74.85%)
# Table (74.61%)
# Line (72.95%)
# Architecture (72.63%)
# Furniture (64.74%)
# Interior design (54.31%)
# Labels (and confidence score):
# ===============================================================================
# Reptile (96.35%)
# Terrestrial animal (92.71%)
# ...
# Wall (78.46%)
# Tree (68.69%)
# Architecture (65.45%)
# World (57.51%)
# Tourism (56.89%)
# Vacation (54.60%)
# Building (53.37%)
# Art (50.22%)
# Labels (and confidence score):
# ===============================================================================
# People (95.36%)
# Social group (91.85%)
# Community (79.56%)
# Event (74.06%)
# Crowd (71.46%)
# Tourism (56.89%)
# Labels (and confidence score):
# ===============================================================================
# Vertebrate (98.51%)
# Guanaco (97.98%)
# Llama (95.63%)
# Vicuña (93.33%)
# Herd (89.88%)
# Wildlife (89.43%)
# Camelid (76.80%)
# Adaptation (74.08%)
# National park (54.88%)
# Labels (and confidence score):
# ===============================================================================
# Blue (96.07%)
# Red (91.54%)
# Sitting (87.42%)
# Standing (79.58%)
# Furniture (73.78%)
# Room (71.39%)
# Adaptation (66.97%)
# Vacation (63.69%)
# Art (62.53%)
# Tourism (60.85%)
# Labels (and confidence score):
# ===============================================================================
# Face (97.68%)
# People (94.15%)
# Turban (92.93%)
# Skin (91.38%)
# Wrinkle (90.86%)
# Head (88.43%)
# Human (82.52%)
# Headgear (75.45%)
# Elder (65.11%)
# Portrait photography (64.75%)
# Labels (and confidence score):
# ===============================================================================
# Mountainous landforms (98.83%)
# Mountain (98.36%)
# Mountain range (95.77%)
# Sky (92.81%)
# Glacial landform (92.01%)
# Natural landscape (88.55%)
# Alps (87.52%)
# Massif (87.24%)
# Winter (86.02%)
# Summit (79.28%)
# Labels (and confidence score):
# ===============================================================================
# Landmark (96.83%)
# Daytime (94.33%)
# Metropolitan area (93.03%)
# Architecture (91.68%)
# Sky (91.27%)
# Building (87.47%)
# City (86.27%)
# Urban area (84.71%)
# Human settlement (83.65%)
# Skyscraper (81.94%)
# Labels (and confidence score):
# ===============================================================================
# Fish (98.31%)
# Fish (96.59%)
# Salmon (71.80%)
# Marine biology (68.22%)
# coho (66.22%)
# Trout (65.90%)
# Bony-fish (61.08%)
# Ray-finned fish (55.94%)
# Salmon-like fish (54.12%)
# Underwater (53.49%)
# Labels (and confidence score):
# ===============================================================================
# Metropolitan area (92.26%)
# City (78.85%)
# Skyscraper (78.63%)
# Urban area (78.01%)
# Architecture (72.63%)
# Metropolis (69.70%)
# Travel (66.95%)
# Shade (55.50%)
# Downtown (51.99%)
# Tourism (51.14%)
# Labels (and confidence score):
# ===============================================================================
# Formation (91.88%)
# Butte (90.86%)
# Rock (89.57%)
# Sky (88.58%)
# Badlands (84.38%)
# Geology (70.18%)
# Cloud (59.49%)
# Landscape (59.31%)
# National park (54.88%)
# Mountain (52.99%)
# Labels (and confidence score):
# ===============================================================================
# Vertebrate (98.51%)
# Mammal (97.58%)
# Hyena (96.16%)
# Terrestrial animal (94.30%)
# Spotted hyena (94.11%)
# Wildlife (91.18%)
# Boar (89.00%)
# Peccary (83.96%)
# Suidae (80.46%)
# Snout (78.40%)
# Labels (and confidence score):
# ===============================================================================
# Mountainous landforms (96.31%)
# Mountain (96.02%)
# Mountaineering (94.89%)
# Snow (91.75%)
# Sky (90.14%)
# Winter (88.49%)
# Mountaineer (88.10%)
# Mountain range (87.91%)
# Adventure (83.26%)
# Arctic (82.13%)
# Labels (and confidence score):
# ===============================================================================
# Formation (92.89%)
# Cave (88.04%)
# Geological phenomenon (87.52%)
# Geology (83.67%)
# Lava cave (77.92%)
# Rock (75.92%)
# Lava tube (75.73%)
# Tree (68.69%)
# Pit cave (67.08%)
# Caving (58.56%)
# Labels (and confidence score):
# ===============================================================================
# Tree (98.77%)
# Branch (98.41%)
# Trunk (89.22%)
# Woody plant (88.99%)
# shellbark hickory (88.43%)
# Plant (85.89%)
# Twig (82.99%)
# Botany (80.09%)
# Wildlife (76.23%)
# Sky (73.26%)
# Labels (and confidence score):
# ===============================================================================
# People in nature (97.88%)
# Sky (96.27%)
# Winter (91.67%)
# Arctic (91.05%)
# Snow (88.76%)
# Freezing (88.16%)
# Natural environment (87.15%)
# Ice (82.34%)
# Cloud (80.34%)
# Ice cap (79.30%)
# Labels (and confidence score):
# ===============================================================================
# Canidae (65.95%)
# Sheep (65.03%)
# Smile (64.11%)
# Sheep (62.50%)
# Sporting Group (61.92%)
# Happy (54.13%)
# Farm (50.82%)
# Labels (and confidence score):
# ===============================================================================
# Sky (94.54%)
# Reflection (85.08%)
# Airplane (78.24%)
# Arctic (77.85%)
# Ocean (76.71%)
# Cloud (74.28%)
# Vehicle (68.69%)
# Sea (68.20%)
# Sea ice (64.65%)
# Ice (64.10%)
# Labels (and confidence score):
# ===============================================================================
# Town (85.18%)
# Street (84.42%)
# Alley (81.05%)
# Infrastructure (75.79%)
# Road (71.34%)
# Architecture (65.45%)
# Photography (62.42%)
# Building (62.30%)
# Temple (61.13%)
# Tourism (56.89%)
# Labels (and confidence score):
# ===============================================================================
# Polar bear (98.81%)
# Bear (97.35%)
# Arctic (97.07%)
# Arctic ocean (93.28%)
# Natural environment (92.87%)
# Sky (92.13%)
# Ocean (91.06%)
# Ice (89.91%)
# Polar ice cap (88.84%)
# Sea ice (88.49%)
# Labels (and confidence score):
# ===============================================================================
# Water (91.00%)
# Town (82.94%)
# Waterway (79.85%)
# Tourism (71.09%)
# Vehicle (63.02%)
# Harbor (60.45%)
# Sea (60.35%)
# Travel (54.82%)
# Vacation (54.60%)
# Coast (53.17%)
# Labels (and confidence score):
# ===============================================================================
# Nature (97.21%)
# Atmospheric phenomenon (95.24%)
# Mist (93.81%)
# Sky (88.58%)
# Natural landscape (88.55%)
# Water (80.73%)
# Tree (77.84%)
# Atmosphere (77.52%)
# Landscape (72.70%)
# Terrain (70.44%)
# Labels (and confidence score):
# ===============================================================================
# Tree (86.46%)
# Tourism (81.04%)
# Palm tree (80.61%)
# Community (79.56%)
# Adaptation (74.08%)
# Arecales (71.95%)
# Crowd (69.16%)
# Leisure (68.10%)
# Temple (64.68%)
# Plant (64.64%)
# Labels (and confidence score):
# ===============================================================================
# Market (94.31%)
# Public space (93.16%)
# People (93.13%)
# Selling (93.02%)
# Marketplace (90.43%)
# Umbrella (90.26%)
# Snapshot (84.34%)
# Human settlement (83.65%)
# Street (80.52%)
# Urban area (78.01%)
# Labels (and confidence score):
# ===============================================================================
# Sky (93.82%)
# Sand (90.93%)
# Natural environment (90.04%)
# Natural landscape (88.55%)
# Sea (81.36%)
# Water (80.73%)
# Horizon (80.53%)
# Shore (71.80%)
# Landscape (68.08%)
# Cloud (66.45%)
# Labels (and confidence score):
# ===============================================================================
# Bird (99.60%)
# Vertebrate (98.51%)
# Bird of prey (95.29%)
# Beak (94.48%)
# Falcon (92.81%)
# Hawk (88.47%)
# Accipitriformes (86.25%)
# Peregrine falcon (84.12%)
# Buzzard (79.27%)
# Adaptation (77.26%)
# Labels (and confidence score):
# ===============================================================================
# Fun (70.39%)
# Tree (68.69%)
# Vacation (60.00%)
# Tourism (56.89%)
# Leisure (56.19%)
# Crowd (50.70%)
# Labels (and confidence score):
# ===============================================================================
# Rhinoceros (98.30%)
# Horn (97.65%)
# White rhinoceros (96.87%)
# Black rhinoceros (95.07%)
# Indian rhinoceros (91.33%)
# Wildlife (87.48%)
# Terrestrial animal (83.19%)
# Working animal (69.03%)
# Wrinkle (67.55%)
# Adaptation (66.97%)
# Labels (and confidence score):
# ===============================================================================
# Science (67.85%)
# Medical assistant (67.24%)
# Research (58.29%)
# Labels (and confidence score):
# ===============================================================================
# People (93.70%)
# Child (80.75%)
# Adaptation (79.12%)
# Sand (77.14%)
# Fun (76.85%)
# Human (74.68%)
# Sitting (70.03%)
# Soil (69.82%)
# Play (67.54%)
# Mud (67.20%)
# [['Rays and skates', 'Fish', 'Underwater', 'Water', 'Manta ray', 'Organism', 'Marine biology', 'Stingray', 'Cartilaginous fish', 'Skate'], ['Photography'], ['Badlands', 'Mountainous landforms', 'Sky', 'Nature', 'Mountain', 'Rock', 'Formation', 'Cloud', 'Wilderness', 'Geology'], ['Rock', 'Tourism', 'Landscape', 'National park'], ['People', 'Community', 'Yellow', 'Tradition', 'Event', 'Temple', 'Tourism', 'Adaptation', 'Sari', 'Smile'], ['Water', 'Photograph', 'Sky', 'Sea', 'Skin', 'Beauty', 'Ocean', 'Vacation', 'Summer', 'Cloud'], ['People in nature', 'Grassland', 'Natural landscape', 'Standing', 'Grass', 'Grass family', 'Ecoregion', 'Sky', 'Field', 'Photography'], ['Plumbing fixture', 'Tile', 'Plumbing', 'Shower'], ['Event', 'Temple'], ['Sky', 'Nature', 'Mountainous landforms', 'Mountain', 'Reflection', 'Light', 'Rock', 'Atmospheric phenomenon', 'Night', 'Atmosphere'], ['Temple', 'Adaptation', 'World'], ['Sky', 'Nature', 'Water', 'Green', 'Natural landscape', 'Cloud', 'Horizon', 'Sea', 'Sound', 'Water resources'], ['Water', 'Tree', 'Landscape', 'Night', 'Geological phenomenon', 'Watercourse', 'Mountain', 'Plant', 'City'], ['Water transportation', 'Harbor', 'Boat', 'Vehicle', 'Fishing vessel', 'Port', 'Transport', 'Water', 'Marina', 'Watercraft'], ['Lion', 'Wildlife', 'Masai lion', 'Big cats', 'Felidae', 'Sky', 'Tree', 'Adaptation', 'Landscape', 'Savanna'], ['Wilderness', 'Tree', 'Botany', 'Soil', 'Grass family', 'Grass', 'Plant', 'Gardener', 'Spring', 'Garden'], ['Tree', 'Sky', 'Blue', 'Woody plant', 'Plant', 'Night', 'Branch', 'Trunk', 'Electric blue', 'Midnight'], ['People in nature', 'Photograph', 'Black', 'Black-and-white', 'Photography', 'Male', 'Monochrome photography', 'Rock', 'Arm', 'Human'], ['Reflection', 'Water', 'Reflecting pool', 'Architecture', 'Symmetry', 'River', 'Water feature'], ['Lady', 'Beauty', 'Lip', 'Fashion', 'Photo shoot', 'Arm', 'Shoulder', 'Flash photography', 'Model', 'Photography'], ['Visual effect lighting', 'Technology', 'Display device', 'Electronic device'], ['Tiger', 'Wildlife', 'Vertebrate', 'Bengal tiger', 'Siberian tiger', 'Mammal', 'Felidae', 'Whiskers', 'Water', 'Terrestrial animal'], ['Wave', 'Ocean', 'Surfing Equipment', 'Surfing', 'Sea', 'Surfboard', 'Coast', 'Wind wave', 'Boardsport', 'Tide'], ['Water', 'Nature', 'Black-and-white', 'Atmospheric phenomenon', 'Monochrome photography', 'Monochrome', 'Tree', 'Rock', 'Geological phenomenon', 'Winter'], ['Army', 'Soldier', 'Military', 'Military uniform', 'Troop', 'Military organization', 'Infantry', 'Military person', 'Marines', 'Military camouflage'], ['Arctic', 'Glacial landform', 'Natural environment', 'Tundra', 'Glacier', 'Wildlife', 'Snow', 'Ice cap', 'Mountain', 'Arctic ocean'], ['Face', 'Facial expression', 'Wrinkle', 'Forehead', 'Skin', 'Head', 'Chin', 'Human', 'Male', 'Cheek'], ['Design', 'Textile', 'Colorfulness', 'Pattern', 'Photography', 'Crowd'], ['Hair', 'Face', 'Beauty', 'Lip', 'Lady', 'Hairstyle', 'Smile', 'Eyebrow', 'Brown hair', 'Chin'], ['Mammal', 'Hyena', 'Vertebrate', 'Wildlife', 'Terrestrial animal', 'Spotted hyena', 'Carnivore', 'Snout', 'Savanna', 'Felidae'], ['Sky', 'Nature', 'Horizon', 'Atmosphere', 'Atmospheric phenomenon', 'Freezing', 'Light', 'Winter', 'Morning', 'Evening'], ['Night'], ['Sky', 'Water', 'Blue', 'Sea', 'Atmosphere', 'Cloud', 'Ocean', 'Horizon', 'Rock', 'Tree'], ['Sky', 'Cloud', 'White', 'Black', 'Black-and-white', 'Nature', 'Monochrome photography', 'Monochrome', 'Water', 'Natural landscape'], ['Yellow', 'Sky', 'Sand', 'Dune', 'Landscape', 'Heat', 'Aeolian landform'], ['Design', 'Room', 'Photography', 'Material property', 'Technology', 'Architecture', 'Black-and-white', 'Collage', 'Interior design', 'Art'], ['Room', 'Photography', 'Sitting'], ['Art'], ['People', 'Green', 'Product', 'Social group', 'Crowd', 'Event', 'Youth', 'Cheering', 'Performance', 'Audience'], ['Soldier', 'Military organization', 'Military', 'Army', 'Military camouflage', 'Infantry', 'Troop', 'Design', 'Marines', 'Military unif ...
# Length of unedited list 500
# [['Rays and skates', 'Fish', 'Underwater', 'Water', 'Manta ray', 'Organism', 'Marine biology', 'Stingray', 'Cartilaginous fish', 'Skate'], ['Photography'], ['Badlands', 'Mountainous landforms', 'Sky', 'Nature', 'Mountain', 'Rock', 'Formation', 'Cloud', 'Wilderness', 'Geology'], ['Rock', 'Tourism', 'Landscape', 'National park'], ['People', 'Community', 'Yellow', 'Tradition', 'Event', 'Temple', 'Tourism', 'Adaptation', 'Sari', 'Smile'], ['Water', 'Photograph', 'Sky', 'Sea', 'Skin', 'Beauty', 'Ocean', 'Vacation', 'Summer', 'Cloud'], ['People in nature', 'Grassland', 'Natural landscape', 'Standing', 'Grass', 'Grass family', 'Ecoregion', 'Sky', 'Field', 'Photography'], ['Plumbing fixture', 'Tile', 'Plumbing', 'Shower'], ['Event', 'Temple'], ['Sky', 'Nature', 'Mountainous landforms', 'Mountain', 'Reflection', 'Light', 'Rock', 'Atmospheric phenomenon', 'Night', 'Atmosphere'], ['Temple', 'Adaptation', 'World'], ['Sky', 'Nature', 'Water', 'Green', 'Natural landscape', 'Cloud', 'Horizon', 'Sea', 'Sound', 'Water resources'], ['Water', 'Tree', 'Landscape', 'Night', 'Geological phenomenon', 'Watercourse', 'Mountain', 'Plant', 'City'], ['Water transportation', 'Harbor', 'Boat', 'Vehicle', 'Fishing vessel', 'Port', 'Transport', 'Water', 'Marina', 'Watercraft'], ['Lion', 'Wildlife', 'Masai lion', 'Big cats', 'Felidae', 'Sky', 'Tree', 'Adaptation', 'Landscape', 'Savanna'], ['Wilderness', 'Tree', 'Botany', 'Soil', 'Grass family', 'Grass', 'Plant', 'Gardener', 'Spring', 'Garden'], ['Tree', 'Sky', 'Blue', 'Woody plant', 'Plant', 'Night', 'Branch', 'Trunk', 'Electric blue', 'Midnight'], ['People in nature', 'Photograph', 'Black', 'Black-and-white', 'Photography', 'Male', 'Monochrome photography', 'Rock', 'Arm', 'Human'], ['Reflection', 'Water', 'Reflecting pool', 'Architecture', 'Symmetry', 'River', 'Water feature'], ['Lady', 'Beauty', 'Lip', 'Fashion', 'Photo shoot', 'Arm', 'Shoulder', 'Flash photography', 'Model', 'Photography'], ['Visual effect lighting', 'Technology', 'Display device', 'Electronic device'], ['Tiger', 'Wildlife', 'Vertebrate', 'Bengal tiger', 'Siberian tiger', 'Mammal', 'Felidae', 'Whiskers', 'Water', 'Terrestrial animal'], ['Wave', 'Ocean', 'Surfing Equipment', 'Surfing', 'Sea', 'Surfboard', 'Coast', 'Wind wave', 'Boardsport', 'Tide'], ['Water', 'Nature', 'Black-and-white', 'Atmospheric phenomenon', 'Monochrome photography', 'Monochrome', 'Tree', 'Rock', 'Geological phenomenon', 'Winter'], ['Army', 'Soldier', 'Military', 'Military uniform', 'Troop', 'Military organization', 'Infantry', 'Military person', 'Marines', 'Military camouflage'], ['Arctic', 'Glacial landform', 'Natural environment', 'Tundra', 'Glacier', 'Wildlife', 'Snow', 'Ice cap', 'Mountain', 'Arctic ocean'], ['Face', 'Facial expression', 'Wrinkle', 'Forehead', 'Skin', 'Head', 'Chin', 'Human', 'Male', 'Cheek'], ['Design', 'Textile', 'Colorfulness', 'Pattern', 'Photography', 'Crowd'], ['Hair', 'Face', 'Beauty', 'Lip', 'Lady', 'Hairstyle', 'Smile', 'Eyebrow', 'Brown hair', 'Chin'], ['Mammal', 'Hyena', 'Vertebrate', 'Wildlife', 'Terrestrial animal', 'Spotted hyena', 'Carnivore', 'Snout', 'Savanna', 'Felidae'], ['Sky', 'Nature', 'Horizon', 'Atmosphere', 'Atmospheric phenomenon', 'Freezing', 'Light', 'Winter', 'Morning', 'Evening'], ['Night'], ['Sky', 'Water', 'Blue', 'Sea', 'Atmosphere', 'Cloud', 'Ocean', 'Horizon', 'Rock', 'Tree'], ['Sky', 'Cloud', 'White', 'Black', 'Black-and-white', 'Nature', 'Monochrome photography', 'Monochrome', 'Water', 'Natural landscape'], ['Yellow', 'Sky', 'Sand', 'Dune', 'Landscape', 'Heat', 'Aeolian landform'], ['Design', 'Room', 'Photography', 'Material property', 'Technology', 'Architecture', 'Black-and-white', 'Collage', 'Interior design', 'Art'], ['Room', 'Photography', 'Sitting'], ['Art'], ['People', 'Green', 'Product', 'Social group', 'Crowd', 'Event', 'Youth', 'Cheering', 'Performance', 'Audience'], ['Soldier', 'Military organization', 'Military', 'Army', 'Military camouflage', 'Infantry', 'Troop', 'Design', 'Marines', 'Military unif ...
# Length of edited list 500

# %%
api_df['Labels'] = ls_of_label_for_url
api_df.index = range(len(api_df.index))
api_df
# Out:
#                                                    URL  \
# 0    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 1    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 2    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 3    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 4    https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# ..                                                 ...
# 495  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 496  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 497  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 498  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 499  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
#
#                                                Caption  Like Count  \
# 0    Photo by @brianskerry | The U.S. Civil War sub...       84699
# 1    Photo by William Albert Allard @williamalberta...      168260
# 2    Photo by David Guttenfelder @dguttenfelder | T...      252696
# 3    Photo by @lucasfogliaphoto | Ashley Klein does...      287042
# 4    Photo by @gerdludwig | Known for their elabora...      149658
# ..                                                 ...         ...
# 495  Photo by Ira Block @irablockphoto | A red-tail...      454383
# 496  Photo by Nora Lorek @noralorek | Three years a...      122497
# 497  Photo by Ami Vitale @amivitale | On Monday, @U...      493142
# 498  Photo by Paolo Woods  and Gabriele Galimberti ...      331186
# 499  Photo by Muhammed Muheisen @mmuheisen | Zahra ...      360826
#
#      Comment Count                                             Labels
# 0              268  [Rays and skates, Fish, Underwater, Water, Man...
# 1              519                                      [Photography]
# 2              491  [Badlands, Mountainous landforms, Sky, Nature,...
# 3             1717          [Rock, Tourism, Landscape, National park]
# 4              394  [People, Community, Yellow, Tradition, Event, ...
# ..             ...                                                ...
# 495           1601  [Bird, Vertebrate, Bird of prey, Beak, Falcon,...
# 496            377     [Fun, Tree, Vacation, Tourism, Leisure, Crowd]
# 497           2411  [Rhinoceros, Horn, White rhinoceros, Black rhi...
# 498           2307             [Science, Medical assistant, Research]
# 499           3251  [People, Child, Adaptation, Sand, Fun, Human, ...
#
# [500 rows x 5 columns]

# %%
export_csv = api_df.to_csv (r'C:\Users\david\Pictures\UGCA\Final\Final_Labeled_Instagram_df.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path

# %% [markdown]
# ## Task A

# %%
df = pd.read_csv(r'Final_Labeled_Instagram_df.csv')

# %%
df.head()
# Out:
#                                                  URL  \
# 0  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 1  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 2  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 3  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 4  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
#
#                                              Caption  Like Count  \
# 0  Photo by @brianskerry | The U.S. Civil War sub...       84699
# 1  Photo by William Albert Allard @williamalberta...      168260
# 2  Photo by David Guttenfelder @dguttenfelder | T...      252696
# 3  Photo by @lucasfogliaphoto | Ashley Klein does...      287042
# 4  Photo by @gerdludwig | Known for their elabora...      149658
#
#    Comment Count                                             Labels
# 0            268  ['Rays and skates', 'Fish', 'Underwater', 'Wat...
# 1            519                                    ['Photography']
# 2            491  ['Badlands', 'Mountainous landforms', 'Sky', '...
# 3           1717  ['Rock', 'Tourism', 'Landscape', 'National park']
# 4            394  ['People', 'Community', 'Yellow', 'Tradition',...

# %%
df["Like Count"] = df["Like Count"]/df["Like Count"].max()
df["Comment Count"] = df["Comment Count"]/df["Comment Count"].max()
df["Engagement Score"] = 0.4* df["Like Count"] + 0.6*df["Comment Count"]


df.loc[df["Engagement Score"]>=df["Engagement Score"].median(), 'Engagement'] = 1
df.loc[df["Engagement Score"]<df["Engagement Score"].median(), 'Engagement'] = 0

# %%
df.head()
# Out:
#                                                  URL  \
# 0  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 1  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 2  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 3  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 4  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
#
#                                              Caption  Like Count  \
# 0  Photo by @brianskerry | The U.S. Civil War sub...    0.048507
# 1  Photo by William Albert Allard @williamalberta...    0.096363
# 2  Photo by David Guttenfelder @dguttenfelder | T...    0.144719
# 3  Photo by @lucasfogliaphoto | Ashley Klein does...    0.164389
# 4  Photo by @gerdludwig | Known for their elabora...    0.085709
#
#    Comment Count                                             Labels  \
# 0       0.020585  ['Rays and skates', 'Fish', 'Underwater', 'Wat...
# 1       0.039865                                    ['Photography']
# 2       0.037714  ['Badlands', 'Mountainous landforms', 'Sky', '...
# 3       0.131884  ['Rock', 'Tourism', 'Landscape', 'National park']
# 4       0.030263  ['People', 'Community', 'Yellow', 'Tradition',...
#
#    Engagement Score  Engagement
# 0          0.031754         0.0
# 1          0.062464         0.0
# 2          0.080516         0.0
# 3          0.144886         1.0
# 4          0.052442         0.0

# %% [markdown]
# ## Task B

# %%
df['Labels1'] = df['Labels'].apply(lambda txt: txt.strip("[]"))

# %%
df = df.reset_index()

# %%
df1 = pd.get_dummies(
    df.set_index('index').Labels1.str \
      .split(',\s*', expand=True).stack()
).groupby(level='index').sum().astype(int).reset_index().drop(["index"],axis=1)

# %%
df1["Engagement"] = df["Engagement"]

# %% [markdown]
# ## Training Labels to predict engagement

# %%
lr = LogisticRegression()
lr.fit(df1.drop(['Engagement'],axis=1),df1.iloc[:,-1])

print("The training accuracy using image labels is: {}".format(lr.score(df1.drop(['Engagement'],axis=1),df1.iloc[:,-1])))
# Out:
# The training accuracy using image labels is: 0.918
# /Users/prajvalgupta/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
data = confusion_matrix(df1.iloc[:,-1], lr.predict(df1.drop(['Engagement'],axis=1)))
df_cm = pd.DataFrame(data, columns=np.unique(df1.iloc[:,-1]), index = np.unique(df1.iloc[:,-1]))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7))
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 16})# font size

# %%
df.head()
# Out:
#    index                                                URL  \
# 0      0  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 1      1  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 2      2  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 3      3  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
# 4      4  https://instagram.fftw1-1.fna.fbcdn.net/v/t51....
#
#                                              Caption  Like Count  \
# 0  Photo by @brianskerry | The U.S. Civil War sub...    0.048507
# 1  Photo by William Albert Allard @williamalberta...    0.096363
# 2  Photo by David Guttenfelder @dguttenfelder | T...    0.144719
# 3  Photo by @lucasfogliaphoto | Ashley Klein does...    0.164389
# 4  Photo by @gerdludwig | Known for their elabora...    0.085709
#
#    Comment Count                                             Labels  \
# 0       0.020585  ['Rays and skates', 'Fish', 'Underwater', 'Wat...
# 1       0.039865                                    ['Photography']
# 2       0.037714  ['Badlands', 'Mountainous landforms', 'Sky', '...
# 3       0.131884  ['Rock', 'Tourism', 'Landscape', 'National park']
# 4       0.030263  ['People', 'Community', 'Yellow', 'Tradition',...
#
#    Engagement Score  Engagement  \
# 0          0.031754         0.0
# 1          0.062464         0.0
# 2          0.080516         0.0
# 3          0.144886         1.0
# 4          0.052442         0.0
#
#                                              Labels1
# 0  'Rays and skates', 'Fish', 'Underwater', 'Wate...
# 1                                      'Photography'
# 2  'Badlands', 'Mountainous landforms', 'Sky', 'N...
# 3    'Rock', 'Tourism', 'Landscape', 'National park'
# 4  'People', 'Community', 'Yellow', 'Tradition', ...

# %%
def remove_stopwords(s):
    stop_words = set(stopwords.words('english'))
    return [w for w in s if not w in stop_words]

# %% [markdown]
# ## Word Frequency Analysis of Labels

# %%
df['Labels'] = df['Labels'].apply(lambda x: ast.literal_eval(x))
count = []

# Count the frequency of the words
for i in range(len(df["Labels"])):
    count += df.iloc[i]["Labels"]

count = [x.lower() for x in count]
word_freq = nltk.FreqDist(count)

# 50 most frequent words
top_words = word_freq.most_common(500)
top_words
# Out:
# [('sky', 150),
#  ('water', 81),
#  ('tree', 78),
#  ('photography', 74),
#  ('wildlife', 74),
#  ('cloud', 55),
#  ('adaptation', 52),
#  ('plant', 46),
#  ('landscape', 44),
#  ('sea', 42),
#  ('mountain', 41),
#  ('rock', 40),
#  ('vertebrate', 40),
#  ('nature', 37),
#  ('human', 37),
#  ('natural landscape', 35),
#  ('terrestrial animal', 35),
#  ('night', 34),
#  ('organism', 32),
#  ('atmospheric phenomenon', 32),
#  ('blue', 32),
#  ('architecture', 32),
#  ('mammal', 32),
#  ('fun', 32),
#  ('tourism', 31),
#  ('room', 31),
#  ('people', 28),
#  ('mountainous landforms', 27),
#  ('atmosphere', 27),
#  ('ocean', 26),
#  ('geological phenomenon', 25),
#  ('vehicle', 25),
#  ('natural environment', 25),
#  ('art', 25),
#  ('smile', 24),
#  ('vacation', 23),
#  ('snout', 23),
#  ('marine biology', 22),
#  ('grass', 22),
#  ('horizon', 22),
#  ('child', 22),
#  ('fish', 20),
#  ('sitting', 20),
#  ('leisure', 20),
#  ('underwater', 19),
#  ('event', 19),
#  ('temple', 19),
#  ('reflection', 19),
#  ('light', 18),
#  ('carnivore', 18),
#  ('morning', 18),
#  ('mountain range', 18),
#  ('formation', 17),
#  ('wilderness', 17),
#  ('grassland', 17),
#  ('black-and-white', 17),
#  ('marine mammal', 17),
#  ('green', 16),
#  ('winter', 16),
#  ('building', 16),
#  ('recreation', 16),
#  ('geology', 15),
#  ('city', 15),
#  ('darkness', 15),
#  ('yellow', 14),
#  ('ice', 14),
#  ('branch', 13),
#  ('monochrome photography', 13),
#  ('evening', 13),
#  ('canidae', 13),
#  ('beak', 13),
#  ('bird', 13),
#  ('tradition', 12),
#  ('felidae', 12),
#  ('woody plant', 12),
#  ('lady', 12),
#  ('wave', 12),
#  ('monochrome', 12),
#  ('arctic', 12),
#  ('crowd', 12),
#  ('urban area', 12),
#  ('house', 12),
#  ('travel', 12),
#  ('stock photography', 12),
#  ('space', 12),
#  ('photograph', 11),
#  ('skin', 11),
#  ('beauty', 11),
#  ('black', 11),
#  ('wall', 11),
#  ('nature reserve', 11),
#  ('male', 10),
#  ('snow', 10),
#  ('reptile', 10),
#  ('highland', 10),
#  ('elephant', 10),
#  ('elephants and mammoths', 10),
#  ('street', 10),
#  ('happy', 10),
#  ('people in nature', 9),
#  ('grass family', 9),
#  ('world', 9),
#  ('river', 9),
#  ('whiskers', 9),
#  ('coast', 9),
#  ('glacial landform', 9),
#  ('sand', 9),
#  ('hill', 9),
#  ('ridge', 9),
#  ('furniture', 9),
#  ('hand', 9),
#  ('headgear', 9),
#  ('lighting', 9),
#  ('rural area', 9),
#  ('african elephant', 9),
#  ('alps', 9),
#  ('cartilaginous fish', 8),
#  ('community', 8),
#  ('field', 8),
#  ('white', 8),
#  ('town', 8),
#  ('dog breed', 8),
#  ('fin', 8),
#  ('safari', 8),
#  ('road', 8),
#  ('landmark', 8),
#  ('shark', 8),
#  ('muscle', 8),
#  ('national park', 7),
#  ('standing', 7),
#  ('ecoregion', 7),
#  ('lion', 7),
#  ('savanna', 7),
#  ('ice cap', 7),
#  ('hair', 7),
#  ('interior design', 7),
#  ('performance', 7),
#  ('dog', 7),
#  ('portrait', 7),
#  ('calm', 7),
#  ('wood', 7),
#  ('red', 7),
#  ('horse', 7),
#  ('tribe', 7),
#  ('leaf', 7),
#  ('vegetation', 7),
#  ('pink', 7),
#  ('forest', 7),
#  ('sea ice', 7),
#  ('car', 7),
#  ('sunlight', 7),
#  ('shore', 7),
#  ('badlands', 6),
#  ('boat', 6),
#  ('big cats', 6),
#  ('botany', 6),
#  ('fashion', 6),
#  ('flash photography', 6),
#  ('glacier', 6),
#  ('arctic ocean', 6),
#  ('face', 6),
#  ('freezing', 6),
#  ('mode of transport', 6),
#  ('coastal and oceanic landforms', 6),
#  ('beach', 6),
#  ('cetacea', 6),
#  ('illustration', 6),
#  ('jungle', 6),
#  ('summit', 6),
#  ('massif', 6),
#  ('metropolitan area', 6),
#  ('human settlement', 6),
#  ('water bird', 6),
#  ('mist', 6),
#  ('great white shark', 6),
#  ('public space', 6),
#  ('silhouette', 6),
#  ('astronomical object', 6),
#  ('flower', 6),
#  ('barechested', 6),
#  ('watercourse', 5),
#  ('water transportation', 5),
#  ('transport', 5),
#  ('masai lion', 5),
#  ('soil', 5),
#  ('trunk', 5),
#  ('electric blue', 5),
#  ('shoulder', 5),
#  ('technology', 5),
#  ('wind wave', 5),
#  ('army', 5),
#  ('soldier', 5),
#  ('military', 5),
#  ('military organization', 5),
#  ('infantry', 5),
#  ('head', 5),
#  ('chin', 5),
#  ('design', 5),
#  ('horn', 5),
#  ('herd', 5),
#  ('sunset', 5),
#  ('costume', 5),
#  ('livestock', 5),
#  ('mane', 5),
#  ('turtle', 5),
#  ('scaled reptile', 5),
#  ('snake', 5),
#  ('polar ice cap', 5),
#  ('fell', 5),
#  ('working animal', 5),
#  ('fog', 5),
#  ('neck', 5),
#  ('games', 5),
#  ('dress', 5),
#  ('ceremony', 5),
#  ('seal', 5),
#  ('cave', 5),
#  ('snapshot', 5),
#  ('indian elephant', 5),
#  ('farm', 5),
#  ('lamniformes', 5),
#  ('lamnidae', 5),
#  ('star', 5),
#  ('spring', 4),
#  ('lip', 4),
#  ('military uniform', 4),
#  ('troop', 4),
#  ('marines', 4),
#  ('military camouflage', 4),
#  ('tundra', 4),
#  ('facial expression', 4),
#  ('textile', 4),
#  ('hairstyle', 4),
#  ('hyena', 4),
#  ('heat', 4),
#  ('aeolian landform', 4),
#  ('social group', 4),
#  ('sporting group', 4),
#  ('nose', 4),
#  ('eye', 4),
#  ('daytime', 4),
#  ('elk', 4),
#  ('deer', 4),
#  ('painting', 4),
#  ('long hair', 4),
#  ('feather', 4),
#  ('aurora', 4),
#  ('plain', 4),
#  ('visual arts', 4),
#  ('green sea turtle', 4),
#  ('ancient history', 4),
#  ('historic site', 4),
#  ('history', 4),
#  ('window', 4),
#  ('serpent', 4),
#  ('fur', 4),
#  ('facial hair', 4),
#  ('elapidae', 4),
#  ('line', 4),
#  ('iceberg', 4),
#  ('cityscape', 4),
#  ('metropolis', 4),
#  ('tiger shark', 4),
#  ('palm tree', 4),
#  ('arecales', 4),
#  ('cool', 4),
#  ('team', 4),
#  ('leg', 4),
#  ('infrastructure', 4),
#  ('wing', 4),
#  ('ritual', 4),
#  ('hill station', 4),
#  ('fur seal', 4),
#  ('thoroughfare', 4),
#  ('gentleman', 4),
#  ('ceiling', 4),
#  ('terrain', 4),
#  ('arch', 4),
#  ('crop', 4),
#  ('bovine', 4),
#  ('waterway', 4),
#  ('screenshot', 4),
#  ('shadow', 4),
#  ('swimming', 4),
#  ('giraffe', 4),
#  ('giraffidae', 4),
#  ('bird of prey', 4),
#  ('dusk', 4),
#  ('skyscraper', 4),
#  ('whale', 4),
#  ('sari', 3),
#  ('summer', 3),
#  ('water resources', 3),
#  ('harbor', 3),
#  ('midnight', 3),
#  ('arm', 3),
#  ('wrinkle', 3),
#  ('spotted hyena', 3),
#  ('dune', 3),
#  ('product', 3),
#  ('youth', 3),
#  ('tower', 3),
#  ('azure', 3),
#  ('home', 3),
#  ('adventure', 3),
#  ('reindeer', 3),
#  ('antler', 3),
#  ('tourist attraction', 3),
#  ('tail', 3),
#  ('sunrise', 3),
#  ('mare', 3),
#  ('flesh', 3),
#  ('bridge', 3),
#  ('pier', 3),
#  ('glasses', 3),
#  ('loggerhead sea turtle', 3),
#  ('sea turtle', 3),
#  ('olive ridley sea turtle', 3),
#  ('hawksbill sea turtle', 3),
#  ("kemp's ridley sea turtle", 3),
#  ('play', 3),
#  ('pond', 3),
#  ('unesco world heritage site', 3),
#  ('asphalt', 3),
#  ('conversation', 3),
#  ('beard', 3),
#  ('macro photography', 3),
#  ('fawn', 3),
#  ('rainforest', 3),
#  ('table', 3),
#  ('blond', 3),
#  ('pasture', 3),
#  ('seabird', 3),
#  ('body of water', 3),
#  ('joint', 3),
#  ('jumping', 3),
#  ('driving', 3),
#  ('auto part', 3),
#  ('sport venue', 3),
#  ('food', 3),
#  ('cuisine', 3),
#  ('umbrella', 3),
#  ('fashion accessory', 3),
#  ('fire', 3),
#  ('flame', 3),
#  ('outerwear', 3),
#  ('harbor seal', 3),
#  ('caving', 3),
#  ('aerial photography', 3),
#  ('bank', 3),
#  ('desert', 3),
#  ('camelid', 3),
#  ('sahara', 3),
#  ('lake', 3),
#  ('agriculture', 3),
#  ('plantation', 3),
#  ('backlighting', 3),
#  ('plant community', 3),
#  ('haze', 3),
#  ('bear', 3),
#  ('tusk', 3),
#  ('circle', 3),
#  ('digital compositing', 3),
#  ('accipitriformes', 3),
#  ('close-up', 3),
#  ('tortoise', 3),
#  ('wind', 3),
#  ('dolphin', 3),
#  ('wadi', 3),
#  ('marsh', 3),
#  ('wetland', 3),
#  ('motor vehicle', 3),
#  ('humpback whale', 3),
#  ('style', 3),
#  ('manta ray', 2),
#  ('sound', 2),
#  ('watercraft', 2),
#  ('garden', 2),
#  ('symmetry', 2),
#  ('tiger', 2),
#  ('bengal tiger', 2),
#  ('siberian tiger', 2),
#  ('surfing equipment', 2),
#  ('boardsport', 2),
#  ('tide', 2),
#  ('military person', 2),
#  ('forehead', 2),
#  ('colorfulness', 2),
#  ('pattern', 2),
#  ('eyebrow', 2),
#  ('brown hair', 2),
#  ('audience', 2),
#  ('statue', 2),
#  ('sculpture', 2),
#  ('town square', 2),
#  ('hunting dog', 2),
#  ('property', 2),
#  ('extreme sport', 2),
#  ('skeleton', 2),
#  ('jaw', 2),
#  ('grazing', 2),
#  ('orange', 2),
#  ('headpiece', 2),
#  ('black hair', 2),
#  ('musical instrument', 2),
#  ('garmon', 2),
#  ('turquoise', 2),
#  ('eyewear', 2),
#  ('watercolor paint', 2),
#  ('cycling', 2),
#  ('bicycle', 2),
#  ('reef', 2),
#  ('fur clothing', 2),
#  ('floor', 2),
#  ('facade', 2),
#  ('real estate', 2),
#  ('stork', 2),
#  ('ciconiiformes', 2),
#  ('outcrop', 2),
#  ('requiem shark', 2),
#  ('carcharhiniformes', 2),
#  ('date palm', 2),
#  ('sleeve', 2),
#  ('gesture', 2),
#  ('personal protective equipment', 2),
#  ('head restraint', 2),
#  ('automotive design', 2),
#  ('family car', 2),
#  ('rein', 2),
#  ('dance', 2),
#  ('clothing', 2),
#  ('smoke', 2),
#  ('human body', 2),
#  ('alley', 2),
#  ('door', 2),
#  ('advertising', 2),
#  ('meteorological phenomenon', 2),
#  ('tunnel', 2),
#  ('lava tube', 2),
#  ("bird's-eye view", 2),
#  ('holy places', 2),
#  ('automotive exterior', 2),
#  ('camel', 2),
#  ('arabian camel', 2),
#  ('three-toed sloth', 2),
#  ('dish', 2),
#  ('cash crop', 2),
#  ('suidae', 2),
#  ('elder', 2),
#  ('underground lake', 2),
#  ('puma', 2),
#  ('picture frame', 2),
#  ('finger', 2),
#  ('mountaineering', 2),
#  ('mountaineer', 2),
#  ('erg', 2),
#  ('lighting accessory', 2),
#  ('glass', 2),
#  ('tints and shades', 2),
#  ('portrait photography', 2),
#  ('music venue', 2),
#  ('open water swimming', 2),
#  ('reservoir', 2),
#  ('terrestrial plant', 2),
#  ('golden eagle', 2),
#  ('eagle', 2),
#  ('hawk', 2),
#  ('falcon', 2),
#  ('accipitridae', 2),
#  ('rodent', 2),
#  ('common bottlenose dolphin', 2),
#  ('spinner dolphin', 2),
#  ('tower block', 2),
#  ('mouth', 2),
#  ('science', 2),
#  ('magenta', 2),
#  ('killer whale', 2),
#  ('automotive window part', 2),
#  ('still life photography', 2),
#  ('woodland', 2),
#  ('meadow', 2),
#  ('mud', 2),
#  ('festival', 2),
#  ('mustang horse', 2),
#  ('seaweed', 2),
#  ('macrocystis', 2),
#  ('pit cave', 2),
#  ('boating', 2),
#  ('petal', 2),
#  ('aquatic plant', 2),
#  ('arcade', 2),
#  ('grey whale', 2),
#  ('old-growth forest', 2),
#  ('california sea lion', 2),
#  ('glacial lake', 2),
#  ('comfort', 2),
#  ('astronomy', 2),
#  ('polar bear', 2),
#  ('lava cave', 2),
#  ('twig', 2)]

# %% [markdown]
# ## Creating Caption Tokens

# %%
df["Caption_Tokens"] =  df["Caption"].apply(lambda x: re.findall(r"[\w']+", x.lower())[3:])
df["Caption_Tokens"] = df["Caption_Tokens"].apply(remove_stopwords)

# %% [markdown]
# ## Word Frequency Analysis of Captions

# %%
count = []

# Count the frequency of the words
for i in range(len(df["Caption_Tokens"])):
    count += df.iloc[i]["Caption_Tokens"]

count = [x.lower() for x in count]
word_freq = nltk.FreqDist(count)

# 50 most frequent words
top_words = word_freq.most_common(500)
top_words
# Out:
# [('follow', 211),
#  ('women', 189),
#  ('world', 183),
#  ('n', 157),
#  ('u2063', 153),
#  ('one', 148),
#  ('like', 116),
#  ('see', 114),
#  ('life', 110),
#  ('stories', 99),
#  ('day', 98),
#  ('images', 92),
#  ('natgeo', 86),
#  ('around', 86),
#  ('years', 85),
#  ('national', 83),
#  ('year', 79),
#  ('people', 77),
#  ('new', 73),
#  ('also', 70),
#  ('photographed', 68),
#  ('many', 68),
#  ('wildlife', 67),
#  ('part', 66),
#  ('water', 66),
#  ('first', 62),
#  ('time', 62),
#  ('next', 61),
#  ('sea', 60),
#  ('south', 54),
#  ('two', 53),
#  ('nature', 53),
#  ('use', 52),
#  ('story', 52),
#  ('today', 52),
#  ('species', 52),
#  ('wild', 52),
#  ('girls', 52),
#  ('week', 50),
#  ('city', 50),
#  ('home', 49),
#  ('000', 49),
#  ('ocean', 48),
#  ('young', 48),
#  ('geo', 48),
#  ('share', 48),
#  ('woman', 48),
#  ('across', 45),
#  ('photos', 45),
#  ('take', 44),
#  ('family', 43),
#  ('work', 43),
#  ('found', 42),
#  ('land', 42),
#  ('long', 42),
#  ('every', 42),
#  ('old', 41),
#  ('conservation', 41),
#  ('since', 41),
#  ('help', 41),
#  ('island', 41),
#  ('u', 40),
#  ('river', 40),
#  ('war', 39),
#  ('park', 39),
#  ('largest', 39),
#  ('back', 39),
#  ('change', 39),
#  ('known', 38),
#  ('children', 38),
#  ('animals', 38),
#  ('three', 38),
#  ('learn', 38),
#  ('last', 38),
#  ('natgeowomenofimpact', 38),
#  ('boundaries', 37),
#  ('inspire', 37),
#  ('generation', 37),
#  ('near', 36),
#  ('may', 36),
#  ('climate', 36),
#  ('would', 36),
#  ('photo', 36),
#  ('elephants', 36),
#  ('celebrating', 36),
#  ('push', 36),
#  ('us', 35),
#  ('environment', 35),
#  ('trees', 35),
#  ('fearlessly', 35),
#  ('project', 34),
#  ('changemakers', 34),
#  ('brianskerry', 33),
#  ('human', 33),
#  ('often', 33),
#  ('find', 33),
#  ('small', 33),
#  ('posts', 33),
#  ('empowered', 33),
#  ('great', 32),
#  ('country', 32),
#  ('get', 32),
#  ('forest', 32),
#  ('ice', 32),
#  ('still', 31),
#  ('night', 31),
#  ('village', 31),
#  ('different', 31),
#  ('along', 31),
#  ('arctic', 31),
#  ('large', 31),
#  ('sharks', 31),
#  ("'s", 30),
#  ('africa', 30),
#  ('even', 30),
#  ('pedromcbride', 30),
#  ('made', 29),
#  ('become', 29),
#  ('community', 29),
#  ('look', 29),
#  ('lives', 29),
#  ('china', 29),
#  ('place', 28),
#  ('live', 28),
#  ('geographic', 28),
#  ('earth', 28),
#  ('way', 28),
#  ('northern', 28),
#  ('followme', 27),
#  ('energy', 27),
#  ('area', 27),
#  ('much', 27),
#  ('million', 27),
#  ('little', 27),
#  ('30', 27),
#  ('school', 27),
#  ('face', 27),
#  ('elephant', 27),
#  ('nnat', 27),
#  ('camp', 26),
#  ('southern', 26),
#  ('waters', 26),
#  ('make', 26),
#  ('left', 26),
#  ('used', 26),
#  ('shark', 26),
#  ('away', 26),
#  ('need', 25),
#  ('history', 25),
#  ('beautiful', 25),
#  ('go', 25),
#  ('fish', 25),
#  ('alaska', 25),
#  ('joelsartore', 25),
#  ('west', 24),
#  ('landscape', 24),
#  ('future', 24),
#  ('female', 24),
#  ('high', 24),
#  ('group', 24),
#  ('camera', 24),
#  ('places', 24),
#  ('living', 24),
#  ('planet', 24),
#  ('photograph', 24),
#  ('working', 24),
#  ('marine', 24),
#  ('islands', 24),
#  ('assignment', 23),
#  ('love', 23),
#  ('50', 23),
#  ('important', 23),
#  ('homes', 23),
#  ('outside', 23),
#  ('simonnorfolkstudio', 23),
#  ('please', 23),
#  ('took', 23),
#  ('ago', 23),
#  ('good', 23),
#  ('month', 23),
#  ('population', 23),
#  ('brown', 23),
#  ('past', 22),
#  ('india', 22),
#  ('summer', 22),
#  ('mountain', 22),
#  ('sponsored', 22),
#  ('dogs', 22),
#  ('far', 22),
#  ('mmuheisen', 22),
#  ('american', 21),
#  ('house', 21),
#  ('called', 21),
#  ('looking', 21),
#  ('mother', 21),
#  ('african', 21),
#  ('ladzinski', 21),
#  ('image', 21),
#  ('animal', 21),
#  ('nat', 21),
#  ('feed', 21),
#  ('seen', 21),
#  ('michaelchristopherbrown', 21),
#  ('amivitale', 21),
#  ('kenya', 21),
#  ('morning', 20),
#  ('de', 20),
#  ('tbfrost', 20),
#  ('ever', 20),
#  ('months', 20),
#  ('photographer', 20),
#  ('second', 20),
#  ('know', 20),
#  ('always', 20),
#  ('2019', 20),
#  ('c', 20),
#  ('jimmychin', 20),
#  ('rock', 20),
#  ('man', 20),
#  ('taken', 20),
#  ('together', 20),
#  ('snake', 20),
#  ('carbon', 20),
#  ('lake', 20),
#  ('region', 20),
#  ('e', 20),
#  ('well', 19),
#  ('book', 19),
#  ('thephotosociety', 19),
#  ('republic', 19),
#  ('behind', 19),
#  ('1', 19),
#  ('north', 19),
#  ('coal', 19),
#  ('uganda', 19),
#  ('parts', 19),
#  ('beach', 19),
#  ('end', 19),
#  ('natural', 19),
#  ('babaktafreshi', 19),
#  ('play', 19),
#  ('birds', 19),
#  ('duke', 19),
#  ('explore', 18),
#  ('making', 18),
#  ('five', 18),
#  ('refugee', 18),
#  ('though', 18),
#  ('3', 18),
#  ('fishing', 18),
#  ('visit', 18),
#  ('shot', 18),
#  ('never', 18),
#  ('climbing', 18),
#  ('food', 18),
#  ('sudan', 18),
#  ('best', 18),
#  ('team', 18),
#  ('might', 18),
#  ('among', 18),
#  ('keep', 18),
#  ('winter', 18),
#  ('beauty', 18),
#  ('special', 18),
#  ('days', 18),
#  ('including', 18),
#  ('florida', 18),
#  ('irablockphoto', 18),
#  ('health', 18),
#  ('america', 17),
#  ('another', 17),
#  ('four', 17),
#  ('endangered', 17),
#  ('big', 17),
#  ('range', 17),
#  ('later', 17),
#  ('began', 17),
#  ('could', 17),
#  ('tree', 17),
#  ('sky', 17),
#  ('feet', 17),
#  ('post', 17),
#  ('open', 17),
#  ('united', 17),
#  ('cave', 17),
#  ('hunting', 17),
#  ('set', 17),
#  ('things', 17),
#  ('skerry', 17),
#  ('horse', 17),
#  ('bhutan', 17),
#  ('farming', 17),
#  ('came', 17),
#  ('soil', 17),
#  ('plastic', 17),
#  ('panther', 17),
#  ('giraffe', 17),
#  ('sussexroyal', 17),
#  ('following', 16),
#  ('art', 16),
#  ('valley', 16),
#  ('border', 16),
#  ('dance', 16),
#  ('age', 16),
#  ('without', 16),
#  ('miles', 16),
#  ('deep', 16),
#  ('photographing', 16),
#  ('want', 16),
#  ('using', 16),
#  ('white', 16),
#  ('several', 16),
#  ('salt', 16),
#  ('ancient', 16),
#  ('taking', 16),
#  ('thousands', 16),
#  ('education', 16),
#  ('christopher', 16),
#  ('communities', 16),
#  ('paulnicklen', 16),
#  ('single', 16),
#  ('mcbride', 16),
#  ('underwater', 15),
#  ('early', 15),
#  ('unique', 15),
#  ('projects', 15),
#  ('says', 15),
#  ('festival', 15),
#  ('due', 15),
#  ('drewtrush', 15),
#  ('central', 15),
#  ('mount', 15),
#  ('survive', 15),
#  ('killed', 15),
#  ('within', 15),
#  ('international', 15),
#  ('went', 15),
#  ('care', 15),
#  ('10', 15),
#  ('photographs', 15),
#  ('male', 15),
#  ('sharing', 15),
#  ('foot', 15),
#  ('wall', 15),
#  ('numbers', 15),
#  ('areas', 15),
#  ('period', 15),
#  ('almost', 15),
#  ('seals', 15),
#  ('state', 14),
#  ('started', 14),
#  ('november', 14),
#  ('hard', 14),
#  ('say', 14),
#  ('inside', 14),
#  ('born', 14),
#  ('six', 14),
#  ('local', 14),
#  ('square', 14),
#  ('able', 14),
#  ('front', 14),
#  ('view', 14),
#  ('close', 14),
#  ('order', 14),
#  ('protect', 14),
#  ('century', 14),
#  ('18', 14),
#  ('states', 14),
#  ('bears', 14),
#  ('decades', 14),
#  ('think', 14),
#  ('incredible', 14),
#  ('plant', 14),
#  ('power', 14),
#  ('global', 14),
#  ('refugees', 14),
#  ('light', 14),
#  ('expedition', 14),
#  ('daughter', 14),
#  ('spent', 14),
#  ('king', 14),
#  ('sun', 14),
#  ('something', 14),
#  ('black', 14),
#  ('western', 14),
#  ('getting', 14),
#  ('heart', 14),
#  ('recent', 14),
#  ('support', 14),
#  ('head', 14),
#  ('travel', 14),
#  ('half', 14),
#  ('photography', 14),
#  ('atmosphere', 14),
#  ('size', 14),
#  ('jasperdoest', 14),
#  ('tennessee', 14),
#  ('lookingup', 14),
#  ('civil', 13),
#  ('portrait', 13),
#  ('start', 13),
#  ('decade', 13),
#  ('career', 13),
#  ('dguttenfelder', 13),
#  ('social', 13),
#  ('culture', 13),
#  ('takes', 13),
#  ('issue', 13),
#  ('top', 13),
#  ('hunt', 13),
#  ('site', 13),
#  ('dina_litovsky', 13),
#  ('series', 13),
#  ('difficult', 13),
#  ('joubert', 13),
#  ('moment', 13),
#  ('extinct', 13),
#  ('stand', 13),
#  ('countries', 13),
#  ('unpublished', 13),
#  ('videos', 13),
#  ('sartore', 13),
#  ('nearly', 13),
#  ('full', 13),
#  ('huge', 13),
#  ('role', 13),
#  ('200', 13),
#  ('shelter', 13),
#  ('lion', 13),
#  ('believe', 13),
#  ('ismailferdous', 13),
#  ('workers', 13),
#  ('ebola', 13),
#  ('weeks', 12),
#  ('research', 12),
#  ('percent', 12),
#  ('agriculture', 12),
#  ('men', 12),
#  ('son', 12),
#  ('husband', 12),
#  ('return', 12),
#  ('ways', 12),
#  ('forests', 12),
#  ('geosteinmetz', 12),
#  ('members', 12),
#  ('died', 12),
#  ('mitty', 12),
#  ('science', 12),
#  ('moments', 12),
#  ('sunset', 12),
#  ('chin', 12),
#  ('market', 12),
#  ('botswana', 12),
#  ('beyond', 12),
#  ('route', 12),
#  ('enough', 12),
#  ('feeding', 12),
#  ('sarahyltonphoto', 12),
#  ('pakistan', 12),
#  ('2018', 12),
#  ('recently', 12),
#  ('stephenwilkes', 12),
#  ('greenland', 12),
#  ('mountains', 12),
#  ('movement', 12),
#  ('antarctica', 12),
#  ('base', 12),
#  ('relationship', 12),
#  ('traditional', 12),
#  ('must', 12),
#  ('air', 12),
#  ('archive', 12),
#  ('lost', 12),
#  ('thomaspeschak', 12),
#  ('amazon', 12),
#  ('vitale', 12),
#  ('capital', 12),
#  ('nfollow', 12),
#  ('seal', 12),
#  ('told', 12),
#  ('subaru_usa', 12),
#  ('underdogs', 12),
#  ('humans', 12),
#  ('body', 12),
#  ('ecosystem', 12),
#  ('lucalocatelliphoto', 12),
#  ('millions', 12),
#  ('nevada', 11),
#  ('california', 11),
#  ('daily', 11),
#  ('said', 11),
#  ('dedicated', 11),
#  ('habitat', 11),
#  ('frost', 11),
#  ('eventually', 11),
#  ('government', 11),
#  ('displaced', 11),
#  ("world's", 11),
#  ('father', 11),
#  ('taylor', 11)]

# %%
df['Caption_Tokens'] = df['Caption_Tokens'].str.join(" ")

# %% [markdown]
# ## Calculating TF-IDF of captions

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
v = TfidfVectorizer()
x = v.fit_transform(df['Caption_Tokens'].tolist())

# %% [markdown]
# ## Selecting top 5 words from each caption that has a high TF-IDF

# %%
tf_idf = pd.DataFrame(x.toarray(), columns = v.get_feature_names()).reset_index()

df_extra = tf_idf.set_index('index')
df_extra = pd.DataFrame(df_extra.columns.values[np.argsort(-df_extra.values, axis=1)[:, :5]], 
                  index=df.index,
                  columns = ['1st Max','2nd Max','3rd Max','4th Max','5th max']).reset_index()

source_col_loc = df_extra.columns.get_loc('1st Max') # column position starts from 0

df_extra['final_captions'] = df_extra.iloc[:,source_col_loc:source_col_loc+5].apply(
    lambda x: ",".join(x.astype(str)), axis=1)

# %%
df_mod = pd.get_dummies(
    df_extra.set_index('index').final_captions.str \
      .split(',\s*', expand=True).stack()
).groupby(level='index').sum().astype(int).reset_index().drop(["index"],axis=1)

df_mod['Engagement'] = df['Engagement']

# %% [markdown]
# ## Training captions to predict engagement

# %%
lr1 = LogisticRegression()
lr1.fit(df_mod.drop(['Engagement'],axis=1),df_mod.iloc[:,-1])

print("The training accuracy using image captions is: {}".format(lr1.score(df_mod.drop(['Engagement'],axis=1),df_mod.iloc[:,-1])))
# Out:
# The training accuracy using image captions is: 0.992
# /Users/prajvalgupta/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
data = confusion_matrix(df_mod.iloc[:,-1], lr1.predict(df_mod.drop(['Engagement'],axis=1)))
df_cm = pd.DataFrame(data, columns=np.unique(df_mod.iloc[:,-1]), index = np.unique(df_mod.iloc[:,-1]))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7))
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 16})# font size

# %%
df_merged = pd.concat([df1,df_mod.drop('Engagement',axis=1)],axis=1)

# %%
lr2 = LogisticRegression()
lr2.fit(df_merged.drop(['Engagement'],axis=1),df_merged['Engagement'])

print("The training accuracy using labels and image captions is: {}".format(lr2.score(df_merged.drop(['Engagement'],axis=1),df_merged['Engagement'])))
# Out:
# The training accuracy using labels and image captions is: 0.998
# /Users/prajvalgupta/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
data = confusion_matrix(df_merged['Engagement'], lr2.predict(df_merged.drop(['Engagement'],axis=1)))
df_cm = pd.DataFrame(data, columns=np.unique(df_merged['Engagement']), index = np.unique(df_merged['Engagement']))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7))
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 16})# font size

# %% [markdown]
# ## Task C
